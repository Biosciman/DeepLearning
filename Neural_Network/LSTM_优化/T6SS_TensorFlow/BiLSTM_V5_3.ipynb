# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, ReLU, Bidirectional,BatchNormalization, Embedding, Conv1D, MaxPool1D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] =False
plt.rcParams.update({"font.size":20})
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, f1_score, recall_score

# %%
negative = pd.read_csv('data/Negative.txt', header = None, index_col=None) 
negative = negative.drop_duplicates()
negative['label'] = 0
positive = pd.read_csv('data/Positive.txt', header = None, index_col=None) 
positive = positive.drop_duplicates()
positive['label'] = 1
# negative[negative.isnull().values==True] # 判断是否存在缺失值

# %%
data = pd.concat([negative, positive], axis=0).reset_index().iloc[:, 1:]
data = data.dropna()

# %%
x_data = data.iloc[:, :-1]
y_data = data.loc[:, 'label']
# 类别均衡化
model_smote = SMOTE()  
x_resampled, y_resampled = model_smote.fit_resample(x_data,y_data)

# %%
# 划分训练数据为80%训练集和20%的验证集
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=7, shuffle=True)

# %%
# # 重置数据维度
# print(x_train.shape)
# x_train = x_train.reshape(-1,1,x_train.shape[-1])
# x_test = x_test.reshape(-1,1,x_test.shape[-1])
# print(x_train.shape)
# Out:
# (1777, 2000)
# (1777, 1, 2000)

# %%
# 对类别数据进行onehot编码
print(y_train.shape)
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)
print(y_train.shape)
# Out:
# (1777,)
# (1777, 2)

# %%
# 构建网络
model = Sequential()
model.add(Embedding(input_dim=21, input_length=2000, output_dim=128,mask_zero=True))
model.add(Conv1D(128,16, activation='relu'))
model.add(Conv1D(64,16, activation='relu'))
model.add(MaxPool1D(pool_size=5,strides=5))

model.add(Bidirectional(LSTM(units=64, return_sequences=True, activation='relu')))
model.add(BatchNormalization())
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())
model.add(Dense(2, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 2000, 128)         2688
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1985, 128)         262272
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1970, 64)          131136
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 394, 64)           0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 394, 128)          66048
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 394, 128)          512
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 128)               98816
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 562,242
# Trainable params: 561,730
# Non-trainable params: 512
# _________________________________________________________________

# %%
# 训练网络
epochs = 100 # 训练周期
batch_size = 64 # 批次大小 
# 监视网络的训练，并将在验证集上取得最优结果的网络权重保留下来
checkpoint = ModelCheckpoint("BiLSTM_V5_3_1.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max') 
# 监视网络的训练，并对学习率进行衰减处理
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=20, verbose=1)
callbacks_list = [checkpoint, reduce_lr] # 监视列表 
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) # 编译网络
# 开始训练，直接使用30%的验证集，在训练过程中测试网络
history = model.fit(x_train, y_train, callbacks=callbacks_list, epochs=epochs, batch_size=batch_size, verbose=1,validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 28/28 [==============================] - ETA: 0s - loss: 0.3968 - accuracy: 0.8272
# Epoch 00001: val_accuracy improved from -inf to 0.53708, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 62s 2s/step - loss: 0.3968 - accuracy: 0.8272 - val_loss: 0.6711 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 2/100
# 28/28 [==============================] - ETA: 0s - loss: 0.1951 - accuracy: 0.9201
# Epoch 00002: val_accuracy improved from 0.53708 to 0.65169, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 59s 2s/step - loss: 0.1951 - accuracy: 0.9201 - val_loss: 0.6734 - val_accuracy: 0.6517 - lr: 0.0010
# Epoch 3/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9775
# Epoch 00003: val_accuracy improved from 0.65169 to 0.67640, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 59s 2s/step - loss: 0.0796 - accuracy: 0.9775 - val_loss: 0.6604 - val_accuracy: 0.6764 - lr: 0.0010
# Epoch 4/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9899
# Epoch 00004: val_accuracy did not improve from 0.67640
# 28/28 [==============================] - 58s 2s/step - loss: 0.0337 - accuracy: 0.9899 - val_loss: 0.7543 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 5/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9910
# Epoch 00005: val_accuracy did not improve from 0.67640
# 28/28 [==============================] - 59s 2s/step - loss: 0.0241 - accuracy: 0.9910 - val_loss: 0.7712 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 6/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9955
# Epoch 00006: val_accuracy did not improve from 0.67640
# 28/28 [==============================] - 59s 2s/step - loss: 0.0185 - accuracy: 0.9955 - val_loss: 0.7141 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 7/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9921
# Epoch 00007: val_accuracy did not improve from 0.67640
# 28/28 [==============================] - 59s 2s/step - loss: 0.0204 - accuracy: 0.9921 - val_loss: 1.4487 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 8/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9893
# Epoch 00008: val_accuracy improved from 0.67640 to 0.80449, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 59s 2s/step - loss: 0.0266 - accuracy: 0.9893 - val_loss: 0.5023 - val_accuracy: 0.8045 - lr: 0.0010
# Epoch 9/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9859
# Epoch 00009: val_accuracy did not improve from 0.80449
# 28/28 [==============================] - 60s 2s/step - loss: 0.0409 - accuracy: 0.9859 - val_loss: 1.6140 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 10/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9893
# Epoch 00010: val_accuracy did not improve from 0.80449
# 28/28 [==============================] - 59s 2s/step - loss: 0.0321 - accuracy: 0.9893 - val_loss: 1.3628 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 11/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9961
# Epoch 00011: val_accuracy improved from 0.80449 to 0.81798, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 60s 2s/step - loss: 0.0180 - accuracy: 0.9961 - val_loss: 0.3798 - val_accuracy: 0.8180 - lr: 0.0010
# Epoch 12/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9938
# Epoch 00012: val_accuracy did not improve from 0.81798
# 28/28 [==============================] - 137s 5s/step - loss: 0.0139 - accuracy: 0.9938 - val_loss: 0.4522 - val_accuracy: 0.7506 - lr: 0.0010
# Epoch 13/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9983
# Epoch 00013: val_accuracy did not improve from 0.81798
# 28/28 [==============================] - 62s 2s/step - loss: 0.0077 - accuracy: 0.9983 - val_loss: 0.5370 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 14/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00014: val_accuracy did not improve from 0.81798
# 28/28 [==============================] - 59s 2s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.8067 - lr: 0.0010
# Epoch 15/100
# 28/28 [==============================] - ETA: 0s - loss: 8.7246e-04 - accuracy: 1.0000
# Epoch 00015: val_accuracy did not improve from 0.81798
# 28/28 [==============================] - 59s 2s/step - loss: 8.7246e-04 - accuracy: 1.0000 - val_loss: 0.6409 - val_accuracy: 0.7596 - lr: 0.0010
# Epoch 16/100
# 28/28 [==============================] - ETA: 0s - loss: 5.1587e-04 - accuracy: 1.0000
# Epoch 00016: val_accuracy did not improve from 0.81798
# 28/28 [==============================] - 60s 2s/step - loss: 5.1587e-04 - accuracy: 1.0000 - val_loss: 0.9114 - val_accuracy: 0.7011 - lr: 0.0010
# Epoch 17/100
# 28/28 [==============================] - ETA: 0s - loss: 2.3459e-04 - accuracy: 1.0000
# Epoch 00017: val_accuracy did not improve from 0.81798
# 28/28 [==============================] - 60s 2s/step - loss: 2.3459e-04 - accuracy: 1.0000 - val_loss: 0.8052 - val_accuracy: 0.7461 - lr: 0.0010
# Epoch 18/100
# 28/28 [==============================] - ETA: 0s - loss: 2.3522e-04 - accuracy: 1.0000
# Epoch 00018: val_accuracy improved from 0.81798 to 0.83820, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 60s 2s/step - loss: 2.3522e-04 - accuracy: 1.0000 - val_loss: 0.5931 - val_accuracy: 0.8382 - lr: 0.0010
# Epoch 19/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8405e-04 - accuracy: 1.0000
# Epoch 00019: val_accuracy improved from 0.83820 to 0.86067, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 61s 2s/step - loss: 1.8405e-04 - accuracy: 1.0000 - val_loss: 0.5534 - val_accuracy: 0.8607 - lr: 0.0010
# Epoch 20/100
# 28/28 [==============================] - ETA: 0s - loss: 1.4849e-04 - accuracy: 1.0000
# Epoch 00020: val_accuracy improved from 0.86067 to 0.86517, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 60s 2s/step - loss: 1.4849e-04 - accuracy: 1.0000 - val_loss: 0.5498 - val_accuracy: 0.8652 - lr: 0.0010
# Epoch 21/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9840e-04 - accuracy: 1.0000
# Epoch 00021: val_accuracy improved from 0.86517 to 0.88539, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 60s 2s/step - loss: 1.9840e-04 - accuracy: 1.0000 - val_loss: 0.4738 - val_accuracy: 0.8854 - lr: 0.0010
# Epoch 22/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0830e-04 - accuracy: 1.0000
# Epoch 00022: val_accuracy improved from 0.88539 to 0.88989, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 60s 2s/step - loss: 2.0830e-04 - accuracy: 1.0000 - val_loss: 0.4734 - val_accuracy: 0.8899 - lr: 0.0010
# Epoch 23/100
# 28/28 [==============================] - ETA: 0s - loss: 1.4567e-04 - accuracy: 1.0000
# Epoch 00023: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 63s 2s/step - loss: 1.4567e-04 - accuracy: 1.0000 - val_loss: 0.5334 - val_accuracy: 0.8831 - lr: 0.0010
# Epoch 24/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7217e-04 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 69s 2s/step - loss: 1.7217e-04 - accuracy: 1.0000 - val_loss: 0.5379 - val_accuracy: 0.8876 - lr: 0.0010
# Epoch 25/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2069e-04 - accuracy: 1.0000
# Epoch 00025: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 66s 2s/step - loss: 1.2069e-04 - accuracy: 1.0000 - val_loss: 0.5539 - val_accuracy: 0.8876 - lr: 0.0010
# Epoch 26/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9462e-04 - accuracy: 1.0000
# Epoch 00026: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 66s 2s/step - loss: 1.9462e-04 - accuracy: 1.0000 - val_loss: 0.6203 - val_accuracy: 0.8809 - lr: 0.0010
# Epoch 27/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2568e-04 - accuracy: 1.0000
# Epoch 00027: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 66s 2s/step - loss: 1.2568e-04 - accuracy: 1.0000 - val_loss: 0.5908 - val_accuracy: 0.8876 - lr: 0.0010
# Epoch 28/100
# 28/28 [==============================] - ETA: 0s - loss: 8.8883e-05 - accuracy: 1.0000
# Epoch 00028: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 64s 2s/step - loss: 8.8883e-05 - accuracy: 1.0000 - val_loss: 0.5805 - val_accuracy: 0.8876 - lr: 0.0010
# Epoch 29/100
# 28/28 [==============================] - ETA: 0s - loss: 8.3795e-05 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 62s 2s/step - loss: 8.3795e-05 - accuracy: 1.0000 - val_loss: 0.5754 - val_accuracy: 0.8876 - lr: 0.0010
# Epoch 30/100
# 28/28 [==============================] - ETA: 0s - loss: 5.6094e-05 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 66s 2s/step - loss: 5.6094e-05 - accuracy: 1.0000 - val_loss: 0.5523 - val_accuracy: 0.8831 - lr: 0.0010
# Epoch 31/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0215e-04 - accuracy: 1.0000
# Epoch 00031: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 66s 2s/step - loss: 1.0215e-04 - accuracy: 1.0000 - val_loss: 0.5551 - val_accuracy: 0.8831 - lr: 0.0010
# Epoch 32/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1199e-04 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 66s 2s/step - loss: 1.1199e-04 - accuracy: 1.0000 - val_loss: 0.5764 - val_accuracy: 0.8854 - lr: 0.0010
# Epoch 33/100
# 28/28 [==============================] - ETA: 0s - loss: 7.7130e-05 - accuracy: 1.0000
# Epoch 00033: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 67s 2s/step - loss: 7.7130e-05 - accuracy: 1.0000 - val_loss: 0.5613 - val_accuracy: 0.8854 - lr: 0.0010
# Epoch 34/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1740e-04 - accuracy: 1.0000
# Epoch 00034: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 65s 2s/step - loss: 1.1740e-04 - accuracy: 1.0000 - val_loss: 0.5737 - val_accuracy: 0.8809 - lr: 0.0010
# Epoch 35/100
# 28/28 [==============================] - ETA: 0s - loss: 5.3305e-05 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.88989
# 28/28 [==============================] - 69s 2s/step - loss: 5.3305e-05 - accuracy: 1.0000 - val_loss: 0.5834 - val_accuracy: 0.8809 - lr: 0.0010
# Epoch 36/100
# 28/28 [==============================] - ETA: 0s - loss: 6.2783e-05 - accuracy: 1.0000
# Epoch 00036: val_accuracy did not improve from 0.88989
# 28/28 [==============================] -
- accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 0.89438
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 28/28 [==============================] - 69s 2s/step - loss: 7.9464e-06 - accuracy: 1.0000 - val_loss: 0.6138 - val_accuracy: 0.8921 - lr: 0.0010
# Epoch 79/100
# 28/28 [==============================] - ETA: 0s - loss: 1.4713e-05 - accuracy: 1.0000
# Epoch 00079: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 71s 3s/step - loss: 1.4713e-05 - accuracy: 1.0000 - val_loss: 0.6144 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 80/100
# 28/28 [==============================] - ETA: 0s - loss: 8.1296e-06 - accuracy: 1.0000
# Epoch 00080: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 66s 2s/step - loss: 8.1296e-06 - accuracy: 1.0000 - val_loss: 0.6157 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 81/100
# 28/28 [==============================] - ETA: 0s - loss: 8.5767e-06 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 64s 2s/step - loss: 8.5767e-06 - accuracy: 1.0000 - val_loss: 0.6151 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 82/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6730e-05 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 64s 2s/step - loss: 1.6730e-05 - accuracy: 1.0000 - val_loss: 0.6152 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 83/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0333e-05 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 64s 2s/step - loss: 1.0333e-05 - accuracy: 1.0000 - val_loss: 0.6157 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 84/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1346e-05 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 64s 2s/step - loss: 1.1346e-05 - accuracy: 1.0000 - val_loss: 0.6180 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 85/100
# 28/28 [==============================] - ETA: 0s - loss: 6.1562e-06 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 65s 2s/step - loss: 6.1562e-06 - accuracy: 1.0000 - val_loss: 0.6175 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 86/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1364e-05 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 66s 2s/step - loss: 1.1364e-05 - accuracy: 1.0000 - val_loss: 0.6181 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 87/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6750e-05 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 65s 2s/step - loss: 1.6750e-05 - accuracy: 1.0000 - val_loss: 0.6179 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 88/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6895e-05 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 68s 2s/step - loss: 1.6895e-05 - accuracy: 1.0000 - val_loss: 0.6192 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 89/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5339e-05 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 66s 2s/step - loss: 1.5339e-05 - accuracy: 1.0000 - val_loss: 0.6261 - val_accuracy: 0.8876 - lr: 5.0000e-04
# Epoch 90/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6068e-05 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 69s 2s/step - loss: 1.6068e-05 - accuracy: 1.0000 - val_loss: 0.6281 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 91/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0724e-05 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 67s 2s/step - loss: 1.0724e-05 - accuracy: 1.0000 - val_loss: 0.6316 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 92/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2729e-05 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 65s 2s/step - loss: 1.2729e-05 - accuracy: 1.0000 - val_loss: 0.6214 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 93/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1504e-05 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 65s 2s/step - loss: 1.1504e-05 - accuracy: 1.0000 - val_loss: 0.6164 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 94/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1879e-05 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 67s 2s/step - loss: 2.1879e-05 - accuracy: 1.0000 - val_loss: 0.6177 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 95/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5764e-05 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 66s 2s/step - loss: 1.5764e-05 - accuracy: 1.0000 - val_loss: 0.6190 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 96/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1742e-05 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 65s 2s/step - loss: 1.1742e-05 - accuracy: 1.0000 - val_loss: 0.6212 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 97/100
# 28/28 [==============================] - ETA: 0s - loss: 2.3529e-05 - accuracy: 1.0000
# Epoch 00097: val_accuracy improved from 0.89438 to 0.89663, saving model to BiLSTM_V5_3_1.h5
# 28/28 [==============================] - 65s 2s/step - loss: 2.3529e-05 - accuracy: 1.0000 - val_loss: 0.6192 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 98/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8861e-05 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 66s 2s/step - loss: 1.8861e-05 - accuracy: 1.0000 - val_loss: 0.6308 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 99/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7881e-05 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 67s 2s/step - loss: 1.7881e-05 - accuracy: 1.0000 - val_loss: 0.6240 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 100/100
# 28/28 [==============================] - ETA: 0s - loss: 7.9820e-06 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 67s 2s/step - loss: 7.9820e-06 - accuracy: 1.0000 - val_loss: 0.6269 - val_accuracy: 0.8921 - lr: 5.0000e-04

# %%
# 可视化训练过程中，训练集与验证集的损失和精度
plt.figure(figsize=(16,8))
plt.subplot(121)
plt.plot(history.history['loss'],label = 'train_loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()

plt.subplot(122)
plt.plot(history.history['accuracy'],label = 'train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
# 使用模型得到预测结果
model = load_model('BiLSTM_V5_3_1.h5')
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
print('在80%训练集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1)), recall_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary'), f1_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary')))
print('在20%测试集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1)), recall_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary'), f1_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary')))
# Out:
# 在80%训练集上, accuracy: 1.0% 召回率:  1.0, f1:  1.0
# 在20%测试集上, accuracy: 0.8966% 召回率: 0.895397489539749, f1: 0.9029535864978904

# %%
# 绘制混淆矩阵
plt.figure(figsize=(16,8))
plt.subplot(121)
matrix = confusion_matrix(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Train confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.subplot(122)
matrix = confusion_matrix(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Test confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.show()
