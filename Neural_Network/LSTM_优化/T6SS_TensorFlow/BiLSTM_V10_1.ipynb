# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, ReLU, Bidirectional,BatchNormalization, Embedding, Conv1D, MaxPool1D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] =False
plt.rcParams.update({"font.size":20})
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, f1_score, recall_score

# %%
negative = pd.read_csv('data/Negative.txt', header = None, index_col=None) 
negative = negative.drop_duplicates()
negative['label'] = 0
positive = pd.read_csv('data/Positive.txt', header = None, index_col=None) 
positive = positive.drop_duplicates()
positive['label'] = 1
# negative[negative.isnull().values==True] # 判断是否存在缺失值

# %%
data = pd.concat([negative, positive], axis=0).reset_index().iloc[:, 1:]
data = data.dropna()

# %%
x_data = data.iloc[:, :-1]
y_data = data.loc[:, 'label']
# 类别均衡化
model_smote = SMOTE()  
x_resampled, y_resampled = model_smote.fit_resample(x_data,y_data)

# %%
# 划分训练数据为80%训练集和20%的验证集
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=7, shuffle=True)

# %%
# # 重置数据维度
# print(x_train.shape)
# x_train = x_train.reshape(-1,1,x_train.shape[-1])
# x_test = x_test.reshape(-1,1,x_test.shape[-1])
# print(x_train.shape)
# Out:
# (1777, 2000)
# (1777, 1, 2000)

# %%
# 对类别数据进行onehot编码
print(y_train.shape)
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)
print(y_train.shape)
# Out:
# (1777,)
# (1777, 2)

# %%
# 构建网络
model = Sequential()
model.add(Embedding(input_dim=21, input_length=2000, output_dim=128))
model.add(Conv1D(128,16, activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPool1D(pool_size=5,strides=5))

model.add(Bidirectional(LSTM(units=64, return_sequences=True, activation='relu')))
model.add(BatchNormalization())
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())
model.add(Dense(2, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 2000, 128)         2688
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1985, 128)         262272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1985, 128)         0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 397, 128)          0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 397, 128)          98816
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 397, 128)          512
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 128)               98816
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 463,874
# Trainable params: 463,362
# Non-trainable params: 512
# _________________________________________________________________

# %%
# 训练网络
epochs = 100 # 训练周期
batch_size = 64 # 批次大小 
# 监视网络的训练，并将在验证集上取得最优结果的网络权重保留下来
checkpoint = ModelCheckpoint("BiLSTM_V10_2.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max') 
# 监视网络的训练，并对学习率进行衰减处理
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=20, verbose=1)
callbacks_list = [checkpoint, reduce_lr] # 监视列表 
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) # 编译网络
# 开始训练，直接使用30%的验证集，在训练过程中测试网络
history = model.fit(x_train, y_train, callbacks=callbacks_list, epochs=epochs, batch_size=batch_size, verbose=1,validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 28/28 [==============================] - ETA: 0s - loss: 0.4525 - accuracy: 0.8030
# Epoch 00001: val_accuracy improved from -inf to 0.53708, saving model to BiLSTM_V10_2.h5
# 28/28 [==============================] - 89s 3s/step - loss: 0.4525 - accuracy: 0.8030 - val_loss: 0.6606 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 2/100
# 28/28 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.8739
# Epoch 00002: val_accuracy improved from 0.53708 to 0.86067, saving model to BiLSTM_V10_2.h5
# 28/28 [==============================] - 86s 3s/step - loss: 0.3151 - accuracy: 0.8739 - val_loss: 0.6206 - val_accuracy: 0.8607 - lr: 0.0010
# Epoch 3/100
# 28/28 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.8942
# Epoch 00003: val_accuracy did not improve from 0.86067
# 28/28 [==============================] - 87s 3s/step - loss: 0.2580 - accuracy: 0.8942 - val_loss: 0.5909 - val_accuracy: 0.8045 - lr: 0.0010
# Epoch 4/100
# 28/28 [==============================] - ETA: 0s - loss: 0.1854 - accuracy: 0.9274
# Epoch 00004: val_accuracy did not improve from 0.86067
# 28/28 [==============================] - 88s 3s/step - loss: 0.1854 - accuracy: 0.9274 - val_loss: 0.5777 - val_accuracy: 0.8427 - lr: 0.0010
# Epoch 5/100
# 28/28 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9432
# Epoch 00005: val_accuracy did not improve from 0.86067
# 28/28 [==============================] - 83s 3s/step - loss: 0.1463 - accuracy: 0.9432 - val_loss: 0.5706 - val_accuracy: 0.7685 - lr: 0.0010
# Epoch 6/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9651
# Epoch 00006: val_accuracy improved from 0.86067 to 0.88315, saving model to BiLSTM_V10_2.h5
# 28/28 [==============================] - 89s 3s/step - loss: 0.0889 - accuracy: 0.9651 - val_loss: 0.5170 - val_accuracy: 0.8831 - lr: 0.0010
# Epoch 7/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9645
# Epoch 00007: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 97s 3s/step - loss: 0.0914 - accuracy: 0.9645 - val_loss: 0.4985 - val_accuracy: 0.8764 - lr: 0.0010
# Epoch 8/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9719
# Epoch 00008: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 126s 5s/step - loss: 0.0673 - accuracy: 0.9719 - val_loss: 0.5082 - val_accuracy: 0.8202 - lr: 0.0010
# Epoch 9/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0594 - accuracy: 0.9775
# Epoch 00009: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 123s 4s/step - loss: 0.0594 - accuracy: 0.9775 - val_loss: 0.5362 - val_accuracy: 0.6607 - lr: 0.0010
# Epoch 10/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9854
# Epoch 00010: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 127s 5s/step - loss: 0.0407 - accuracy: 0.9854 - val_loss: 0.8210 - val_accuracy: 0.5011 - lr: 0.0010
# Epoch 11/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9876
# Epoch 00011: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 119s 4s/step - loss: 0.0405 - accuracy: 0.9876 - val_loss: 1.1162 - val_accuracy: 0.4787 - lr: 0.0010
# Epoch 12/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9842
# Epoch 00012: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 89s 3s/step - loss: 0.0407 - accuracy: 0.9842 - val_loss: 0.9617 - val_accuracy: 0.5101 - lr: 0.0010
# Epoch 13/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9887
# Epoch 00013: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0347 - accuracy: 0.9887 - val_loss: 0.3504 - val_accuracy: 0.8315 - lr: 0.0010
# Epoch 14/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9871
# Epoch 00014: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0488 - accuracy: 0.9871 - val_loss: 0.8747 - val_accuracy: 0.6584 - lr: 0.0010
# Epoch 15/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9848
# Epoch 00015: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 90s 3s/step - loss: 0.0422 - accuracy: 0.9848 - val_loss: 0.3643 - val_accuracy: 0.8607 - lr: 0.0010
# Epoch 16/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9747
# Epoch 00016: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 85s 3s/step - loss: 0.0668 - accuracy: 0.9747 - val_loss: 0.3679 - val_accuracy: 0.8337 - lr: 0.0010
# Epoch 17/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9876
# Epoch 00017: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 82s 3s/step - loss: 0.0338 - accuracy: 0.9876 - val_loss: 0.5380 - val_accuracy: 0.7798 - lr: 0.0010
# Epoch 18/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9955
# Epoch 00018: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0165 - accuracy: 0.9955 - val_loss: 2.3226 - val_accuracy: 0.5348 - lr: 0.0010
# Epoch 19/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9938
# Epoch 00019: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 85s 3s/step - loss: 0.0207 - accuracy: 0.9938 - val_loss: 1.3445 - val_accuracy: 0.6022 - lr: 0.0010
# Epoch 20/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9944
# Epoch 00020: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0188 - accuracy: 0.9944 - val_loss: 2.7796 - val_accuracy: 0.5573 - lr: 0.0010
# Epoch 21/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9921
# Epoch 00021: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0210 - accuracy: 0.9921 - val_loss: 1.0662 - val_accuracy: 0.7146 - lr: 0.0010
# Epoch 22/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9927
# Epoch 00022: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0184 - accuracy: 0.9927 - val_loss: 2.0937 - val_accuracy: 0.6022 - lr: 0.0010
# Epoch 23/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9949
# Epoch 00023: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 86s 3s/step - loss: 0.0165 - accuracy: 0.9949 - val_loss: 2.1426 - val_accuracy: 0.5888 - lr: 0.0010
# Epoch 24/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9972
# Epoch 00024: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 2.6122 - val_accuracy: 0.5596 - lr: 0.0010
# Epoch 25/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9949
# Epoch 00025: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0197 - accuracy: 0.9949 - val_loss: 3.5843 - val_accuracy: 0.5461 - lr: 0.0010
# Epoch 26/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9944
# Epoch 00026: val_accuracy did not improve from 0.88315
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 28/28 [==============================] - 83s 3s/step - loss: 0.0153 - accuracy: 0.9944 - val_loss: 3.0725 - val_accuracy: 0.5708 - lr: 0.0010
# Epoch 27/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9938
# Epoch 00027: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0171 - accuracy: 0.9938 - val_loss: 3.8008 - val_accuracy: 0.5169 - lr: 5.0000e-04
# Epoch 28/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9910
# Epoch 00028: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0218 - accuracy: 0.9910 - val_loss: 3.5347 - val_accuracy: 0.5191 - lr: 5.0000e-04
# Epoch 29/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9989
# Epoch 00029: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0073 - accuracy: 0.9989 - val_loss: 1.6836 - val_accuracy: 0.6607 - lr: 5.0000e-04
# Epoch 30/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9977
# Epoch 00030: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 2.4828 - val_accuracy: 0.5955 - lr: 5.0000e-04
# Epoch 31/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9994
# Epoch 00031: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 82s 3s/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 2.5259 - val_accuracy: 0.5955 - lr: 5.0000e-04
# Epoch 32/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9989
# Epoch 00032: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 82s 3s/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 2.7812 - val_accuracy: 0.5865 - lr: 5.0000e-04
# Epoch 33/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9989
# Epoch 00033: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 3.4327 - val_accuracy: 0.5618 - lr: 5.0000e-04
# Epoch 34/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9989
# Epoch 00034: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 2.6410 - val_accuracy: 0.6022 - lr: 5.0000e-04
# Epoch 35/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9983
# Epoch 00035: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 1.7415 - val_accuracy: 0.6921 - lr: 5.0000e-04
# Epoch 36/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9994
# Epoch 00036: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0036 - accuracy: 0.9994 - val_loss: 3.2219 - val_accuracy: 0.5775 - lr: 5.0000e-04
# Epoch 37/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9994
# Epoch 00037: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 1.9957 - val_accuracy: 0.6562 - lr: 5.0000e-04
# Epoch 38/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9977
# Epoch 00038: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0055 - accuracy: 0.9977 - val_loss: 2.3055 - val_accuracy: 0.6315 - lr: 5.0000e-04
# Epoch 39/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9989
# Epoch 00039: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 2.8555 - val_accuracy: 0.5955 - lr: 5.0000e-04
# Epoch 40/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9983
# Epoch 00040: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0040 - accuracy: 0.9983 - val_loss: 4.1843 - val_accuracy: 0.5124 - lr: 5.0000e-04
# Epoch 41/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9989
# Epoch 00041: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 85s 3s/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 2.5994 - val_accuracy: 0.6067 - lr: 5.0000e-04
# Epoch 42/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9989
# Epoch 00042: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 1.7394 - val_accuracy: 0.7079 - lr: 5.0000e-04
# Epoch 43/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.6160 - val_accuracy: 0.6382 - lr: 5.0000e-04
# Epoch 44/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9972
# Epoch 00044: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0071 - accuracy: 0.9972 - val_loss: 4.9857 - val_accuracy: 0.5281 - lr: 5.0000e-04
# Epoch 45/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9983
# Epoch 00045: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 3.2103 - val_accuracy: 0.5910 - lr: 5.0000e-04
# Epoch 46/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.88315
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 28/28 [==============================] - 83s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.7818 - val_accuracy: 0.5843 - lr: 5.0000e-04
# Epoch 47/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9983
# Epoch 00047: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0041 - accuracy: 0.9983 - val_loss: 2.0618 - val_accuracy: 0.6764 - lr: 2.5000e-04
# Epoch 48/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 00048: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 1.5903 - val_accuracy: 0.7258 - lr: 2.5000e-04
# Epoch 49/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9994
# Epoch 00049: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 2.4412 - val_accuracy: 0.6494 - lr: 2.5000e-04
# Epoch 50/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 00050: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 2339s 84s/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 1.7949 - val_accuracy: 0.7101 - lr: 2.5000e-04
# Epoch 51/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 14404s 514s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.4679 - val_accuracy: 0.7506 - lr: 2.5000e-04
# Epoch 52/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9989
# Epoch 00052: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 19996s 714s/step - loss: 0.0017 - accuracy: 0.9989 - val_loss: 1.6716 - val_accuracy: 0.7236 - lr: 2.5000e-04
# Epoch 53/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994
# Epoch 00053: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 224s 8s/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 1.5713 - val_accuracy: 0.7438 - lr: 2.5000e-04
# Epoch 54/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00054: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 182s 6s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.4940 - val_accuracy: 0.6315 - lr: 2.5000e-04
# Epoch 55/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 00055: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 182s 6s/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 2.4645 - val_accuracy: 0.6337 - lr: 2.5000e-04
# Epoch 56/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 182s 6s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.0450 - val_accuracy: 0.5978 - lr: 2.5000e-04
# Epoch 57/100
# 28/28 [==============================] - ETA: 0s - loss: 5.6090e-04 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 179s 6s/step - loss: 5.6090e-04 - accuracy: 1.0000 - val_loss: 2.7452 - val_accuracy: 0.6135 - lr: 2.5000e-04
# Epoch 58/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 00058: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 206s 7s/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 2.1928 - val_accuracy: 0.6404 - lr: 2.5000e-04
# Epoch 59/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9994
# Epoch 00059: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 195s 7s/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 2.6147 - val_accuracy: 0.6022 - lr: 2.5000e-04
# Epoch 60/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9994
# Epoch 00060: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 189s 7s/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 4.3004 - val_accuracy: 0.5213 - lr: 2.5000e-04
# Epoch 61/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9994
# Epoch 00061: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 186s 7s/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 2.4786 - val_accuracy: 0.6270 - lr: 2.5000e-04
# Epoch 62/100
# 28/28 [==============================] - ETA: 0s - loss: 8.2796e-04 - accuracy: 1.0000
# Epoch 00062: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 219s 8s/step - loss: 8.2796e-04 - accuracy: 1.0000 - val_loss: 2.6311 - val_accuracy: 0.6157 - lr: 2.5000e-04
# Epoch 63/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 00063: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 216s 8s/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 3.1927 - val_accuracy: 0.5775 - lr: 2.5000e-04
# Epoch 64/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 00064: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 218s 8s/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 2.9063 - val_accuracy: 0.5843 - lr: 2.5000e-04
# Epoch 65/100
# 28/28 [==============================] - ETA: 0s - loss: 9.5673e-04 - accuracy: 1.0000
# Epoch 00065: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 218s 8s/step - loss: 9.5673e-04 - accuracy: 1.0000 - val_loss: 2.6977 - val_accuracy: 0.6022 - lr: 2.5000e-04
# Epoch 66/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994
# Epoch 00066: val_accuracy did not improve from 0.88315
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 28/28 [==============================] - 219s 8s/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 2.3785 - val_accuracy: 0.6270 - lr: 2.5000e-04
# Epoch 67/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994
# Epoch 00067: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 218s 8s/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 2.5811 - val_accuracy: 0.6090 - lr: 1.2500e-04
# Epoch 68/100
# 28/28 [==============================] - ETA: 0s - loss: 4.1445e-04 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 218s 8s/step - loss: 4.1445e-04 - accuracy: 1.0000 - val_loss: 2.6766 - val_accuracy: 0.6045 - lr: 1.2500e-04
# Epoch 69/100
# 28/28 [==============================] - ETA: 0s - loss: 5.8114e-04 - accuracy: 1.0000
# Epoch 00069: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 223s 8s/step - loss: 5.8114e-04 - accuracy: 1.0000 - val_loss: 2.7736 - val_accuracy: 0.5955 - lr: 1.2500e-04
# Epoch 70/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 00070: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 3358s 120s/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 2.9310 - val_accuracy: 0.5843 - lr: 1.2500e-04
# Epoch 71/100
# 28/28 [==============================] - ETA: 0s - loss: 4.5319e-04 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 81s 3s/step - loss: 4.5319e-04 - accuracy: 1.0000 - val_loss: 2.8989 - val_accuracy: 0.5843 - lr: 1.2500e-04
# Epoch 72/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9994
# Epoch 00072: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 84s 3s/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 2.8008 - val_accuracy: 0.5955 - lr: 1.2500e-04
# Epoch 73/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 80s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.5196 - val_accuracy: 0.5708 - lr: 1.2500e-04
# Epoch 74/100
# 28/28 [==============================] - ETA: 0s - loss: 6.3482e-04 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 82s 3s/step - loss: 6.3482e-04 - accuracy: 1.0000 - val_loss: 3.3192 - val_accuracy: 0.5775 - lr: 1.2500e-04
# Epoch 75/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9994
# Epoch 00075: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 82s 3s/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 2.7316 - val_accuracy: 0.5978 - lr: 1.2500e-04
# Epoch 76/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 00076: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 81s 3s/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 3.7071 - val_accuracy: 0.5708 - lr: 1.2500e-04
# Epoch 77/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994
# Epoch 00077: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 81s 3s/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 2.7504 - val_accuracy: 0.6045 - lr: 1.2500e-04
# Epoch 78/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994
# Epoch 00078: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 81s 3s/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 2.0066 - val_accuracy: 0.6697 - lr: 1.2500e-04
# Epoch 79/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994
# Epoch 00079: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 81s 3s/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 2.8306 - val_accuracy: 0.5955 - lr: 1.2500e-04
# Epoch 80/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00080: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 81s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.3520 - val_accuracy: 0.6404 - lr: 1.2500e-04
# Epoch 81/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9989
# Epoch 00081: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 81s 3s/step - loss: 0.0014 - accuracy: 0.9989 - val_loss: 2.7526 - val_accuracy: 0.5955 - lr: 1.2500e-04
# Epoch 82/100
# 28/28 [==============================] - ETA: 0s - loss: 6.5197e-04 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 6.5197e-04 - accuracy: 1.0000 - val_loss: 2.6421 - val_accuracy: 0.6000 - lr: 1.2500e-04
# Epoch 83/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 81s 3s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.4337 - val_accuracy: 0.6090 - lr: 1.2500e-04
# Epoch 84/100
# 28/28 [==============================] - ETA: 0s - loss: 6.9009e-04 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 81s 3s/step - loss: 6.9009e-04 - accuracy: 1.0000 - val_loss: 2.5761 - val_accuracy: 0.6045 - lr: 1.2500e-04
# Epoch 85/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 00085: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 82s 3s/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 2.4920 - val_accuracy: 0.6112 - lr: 1.2500e-04
# Epoch 86/100
# 28/28 [==============================] - ETA: 0s - loss: 3.8514e-04 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.88315
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 28/28 [==============================] - 82s 3s/step - loss: 3.8514e-04 - accuracy: 1.0000 - val_loss: 2.9463 - val_accuracy: 0.5910 - lr: 1.2500e-04
# Epoch 87/100
# 28/28 [==============================] - ETA: 0s - loss: 4.6516e-04 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 82s 3s/step - loss: 4.6516e-04 - accuracy: 1.0000 - val_loss: 3.0107 - val_accuracy: 0.5888 - lr: 6.2500e-05
# Epoch 88/100
# 28/28 [==============================] - ETA: 0s - loss: 2.2616e-04 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 83s 3s/step - loss: 2.2616e-04 - accuracy: 1.0000 - val_loss: 3.0191 - val_accuracy: 0.5888 - lr: 6.2500e-05
# Epoch 89/100
# 28/28 [==============================] - ETA: 0s - loss: 5.6032e-04 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 82s 3s/step - loss: 5.6032e-04 - accuracy: 1.0000 - val_loss: 3.1077 - val_accuracy: 0.5865 - lr: 6.2500e-05
# Epoch 90/100
# 28/28 [==============================] - ETA: 0s - loss: 5.1855e-04 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 70s 3s/step - loss: 5.1855e-04 - accuracy: 1.0000 - val_loss: 3.0611 - val_accuracy: 0.5865 - lr: 6.2500e-05
# Epoch 91/100
# 28/28 [==============================] - ETA: 0s - loss: 5.8204e-04 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 48s 2s/step - loss: 5.8204e-04 - accuracy: 1.0000 - val_loss: 3.2258 - val_accuracy: 0.5865 - lr: 6.2500e-05
# Epoch 92/100
# 28/28 [==============================] - ETA: 0s - loss: 5.3093e-04 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 54s 2s/step - loss: 5.3093e-04 - accuracy: 1.0000 - val_loss: 3.2793 - val_accuracy: 0.5820 - lr: 6.2500e-05
# Epoch 93/100
# 28/28 [==============================] - ETA: 0s - loss: 6.1238e-04 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 52s 2s/step - loss: 6.1238e-04 - accuracy: 1.0000 - val_loss: 3.3323 - val_accuracy: 0.5775 - lr: 6.2500e-05
# Epoch 94/100
# 28/28 [==============================] - ETA: 0s - loss: 9.3541e-04 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 47s 2s/step - loss: 9.3541e-04 - accuracy: 1.0000 - val_loss: 2.8517 - val_accuracy: 0.5933 - lr: 6.2500e-05
# Epoch 95/100
# 28/28 [==============================] - ETA: 0s - loss: 5.3636e-04 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 47s 2s/step - loss: 5.3636e-04 - accuracy: 1.0000 - val_loss: 2.8560 - val_accuracy: 0.5888 - lr: 6.2500e-05
# Epoch 96/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994
# Epoch 00096: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 48s 2s/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 3.1686 - val_accuracy: 0.5843 - lr: 6.2500e-05
# Epoch 97/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0880e-04 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 47s 2s/step - loss: 2.0880e-04 - accuracy: 1.0000 - val_loss: 3.1546 - val_accuracy: 0.5865 - lr: 6.2500e-05
# Epoch 98/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 00098: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 48s 2s/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 2.3287 - val_accuracy: 0.6360 - lr: 6.2500e-05
# Epoch 99/100
# 28/28 [==============================] - ETA: 0s - loss: 8.7045e-04 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 48s 2s/step - loss: 8.7045e-04 - accuracy: 1.0000 - val_loss: 2.7966 - val_accuracy: 0.5978 - lr: 6.2500e-05
# Epoch 100/100
# 28/28 [==============================] - ETA: 0s - loss: 4.0361e-04 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 47s 2s/step - loss: 4.0361e-04 - accuracy: 1.0000 - val_loss: 2.9966 - val_accuracy: 0.5865 - lr: 6.2500e-05

# %%
# 可视化训练过程中，训练集与验证集的损失和精度
plt.figure(figsize=(16,8))
plt.subplot(121)
plt.plot(history.history['loss'],label = 'train_loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()

plt.subplot(122)
plt.plot(history.history['accuracy'],label = 'train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
# 使用模型得到预测结果
model = load_model('BiLSTM_V10_2.h5')
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
print('在80%训练集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1)), recall_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary'), f1_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary')))
print('在20%测试集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1)), recall_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary'), f1_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary')))
# Out:
# 在80%训练集上, accuracy: 0.9207% 召回率: 0.8979357798165137, f1: 0.9173989455184535
# 在20%测试集上, accuracy: 0.8831% 召回率: 0.8828451882845189, f1: 0.890295358649789

# %%
# 绘制混淆矩阵
plt.figure(figsize=(16,8))
plt.subplot(121)
matrix = confusion_matrix(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Train confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.subplot(122)
matrix = confusion_matrix(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Test confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.show()
