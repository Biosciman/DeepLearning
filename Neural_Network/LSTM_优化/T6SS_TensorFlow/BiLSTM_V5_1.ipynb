# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, ReLU, Bidirectional,BatchNormalization, Embedding, Conv1D, MaxPool1D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] =False
plt.rcParams.update({"font.size":20})
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, f1_score, recall_score

# %%
negative = pd.read_csv('data/Negative.txt', header = None, index_col=None) 
negative = negative.drop_duplicates()
negative['label'] = 0
positive = pd.read_csv('data/Positive.txt', header = None, index_col=None) 
positive = positive.drop_duplicates()
positive['label'] = 1
# negative[negative.isnull().values==True] # 判断是否存在缺失值

# %%
data = pd.concat([negative, positive], axis=0).reset_index().iloc[:, 1:]
data = data.dropna()

# %%
x_data = data.iloc[:, :-1]
y_data = data.loc[:, 'label']
# 类别均衡化
model_smote = SMOTE()  
x_resampled, y_resampled = model_smote.fit_resample(x_data,y_data)

# %%
# 划分训练数据为80%训练集和20%的验证集
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=7, shuffle=True)

# %%
# # 重置数据维度
# print(x_train.shape)
# x_train = x_train.reshape(-1,1,x_train.shape[-1])
# x_test = x_test.reshape(-1,1,x_test.shape[-1])
# print(x_train.shape)
# Out:
# (1777, 2000)
# (1777, 1, 2000)

# %%
# 对类别数据进行onehot编码
print(y_train.shape)
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)
print(y_train.shape)
# Out:
# (1777,)
# (1777, 2)

# %%
# 构建网络
model = Sequential()
model.add(Embedding(input_dim=21, input_length=2000, output_dim=128))
model.add(Conv1D(128,16, activation='relu'))
model.add(Conv1D(64,16, activation='relu'))
model.add(MaxPool1D(pool_size=5,strides=5))

model.add(Bidirectional(LSTM(units=64, return_sequences=True, activation='relu')))
model.add(BatchNormalization())
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())
model.add(Dense(2, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2000, 128)         2688
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1985, 128)         262272
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1970, 64)          131136
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 394, 64)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 394, 128)          66048
# _________________________________________________________________
# batch_normalization (BatchNo (None, 394, 128)          512
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               98816
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 562,242
# Trainable params: 561,730
# Non-trainable params: 512
# _________________________________________________________________

# %%
# 训练网络
epochs = 100 # 训练周期
batch_size = 64 # 批次大小 
# 监视网络的训练，并将在验证集上取得最优结果的网络权重保留下来
checkpoint = ModelCheckpoint("BiLSTM_V5_2.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max') 
# 监视网络的训练，并对学习率进行衰减处理
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=20, verbose=1)
callbacks_list = [checkpoint, reduce_lr] # 监视列表 
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) # 编译网络
# 开始训练，直接使用30%的验证集，在训练过程中测试网络
history = model.fit(x_train, y_train, callbacks=callbacks_list, epochs=epochs, batch_size=batch_size, verbose=1,validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 28/28 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.8137
# Epoch 00001: val_accuracy improved from -inf to 0.53708, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 61s 2s/step - loss: 0.4096 - accuracy: 0.8137 - val_loss: 0.6830 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 2/100
# 28/28 [==============================] - ETA: 0s - loss: 0.2269 - accuracy: 0.9145
# Epoch 00002: val_accuracy improved from 0.53708 to 0.65169, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 60s 2s/step - loss: 0.2269 - accuracy: 0.9145 - val_loss: 0.6704 - val_accuracy: 0.6517 - lr: 0.0010
# Epoch 3/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9736
# Epoch 00003: val_accuracy improved from 0.65169 to 0.67416, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 61s 2s/step - loss: 0.0820 - accuracy: 0.9736 - val_loss: 0.6683 - val_accuracy: 0.6742 - lr: 0.0010
# Epoch 4/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0526 - accuracy: 0.9831
# Epoch 00004: val_accuracy improved from 0.67416 to 0.83596, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 61s 2s/step - loss: 0.0526 - accuracy: 0.9831 - val_loss: 0.6338 - val_accuracy: 0.8360 - lr: 0.0010
# Epoch 5/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9932
# Epoch 00005: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 66s 2s/step - loss: 0.0276 - accuracy: 0.9932 - val_loss: 0.6688 - val_accuracy: 0.4652 - lr: 0.0010
# Epoch 6/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9955
# Epoch 00006: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 63s 2s/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.7428 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 7/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 00007: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 59s 2s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.8566 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 8/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00008: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 63s 2s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.9224 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 9/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00009: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 64s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.9320 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 10/100
# 28/28 [==============================] - ETA: 0s - loss: 9.3905e-04 - accuracy: 1.0000
# Epoch 00010: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 64s 2s/step - loss: 9.3905e-04 - accuracy: 1.0000 - val_loss: 0.8959 - val_accuracy: 0.4652 - lr: 0.0010
# Epoch 11/100
# 28/28 [==============================] - ETA: 0s - loss: 4.0337e-04 - accuracy: 1.0000
# Epoch 00011: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 62s 2s/step - loss: 4.0337e-04 - accuracy: 1.0000 - val_loss: 0.8558 - val_accuracy: 0.4876 - lr: 0.0010
# Epoch 12/100
# 28/28 [==============================] - ETA: 0s - loss: 5.1163e-04 - accuracy: 1.0000
# Epoch 00012: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 61s 2s/step - loss: 5.1163e-04 - accuracy: 1.0000 - val_loss: 0.7584 - val_accuracy: 0.5483 - lr: 0.0010
# Epoch 13/100
# 28/28 [==============================] - ETA: 0s - loss: 2.6703e-04 - accuracy: 1.0000
# Epoch 00013: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 65s 2s/step - loss: 2.6703e-04 - accuracy: 1.0000 - val_loss: 0.7028 - val_accuracy: 0.6157 - lr: 0.0010
# Epoch 14/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0527e-04 - accuracy: 1.0000
# Epoch 00014: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 61s 2s/step - loss: 2.0527e-04 - accuracy: 1.0000 - val_loss: 0.6775 - val_accuracy: 0.6539 - lr: 0.0010
# Epoch 15/100
# 28/28 [==============================] - ETA: 0s - loss: 2.7395e-04 - accuracy: 1.0000
# Epoch 00015: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 60s 2s/step - loss: 2.7395e-04 - accuracy: 1.0000 - val_loss: 0.5204 - val_accuracy: 0.7730 - lr: 0.0010
# Epoch 16/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0093e-04 - accuracy: 1.0000
# Epoch 00016: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 60s 2s/step - loss: 2.0093e-04 - accuracy: 1.0000 - val_loss: 0.4410 - val_accuracy: 0.8337 - lr: 0.0010
# Epoch 17/100
# 28/28 [==============================] - ETA: 0s - loss: 2.9111e-04 - accuracy: 1.0000
# Epoch 00017: val_accuracy did not improve from 0.83596
# 28/28 [==============================] - 65s 2s/step - loss: 2.9111e-04 - accuracy: 1.0000 - val_loss: 0.4471 - val_accuracy: 0.8360 - lr: 0.0010
# Epoch 18/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1015e-04 - accuracy: 1.0000
# Epoch 00018: val_accuracy improved from 0.83596 to 0.86742, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 65s 2s/step - loss: 2.1015e-04 - accuracy: 1.0000 - val_loss: 0.4065 - val_accuracy: 0.8674 - lr: 0.0010
# Epoch 19/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8142e-04 - accuracy: 1.0000
# Epoch 00019: val_accuracy improved from 0.86742 to 0.89438, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 65s 2s/step - loss: 1.8142e-04 - accuracy: 1.0000 - val_loss: 0.3431 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 20/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3244e-04 - accuracy: 1.0000
# Epoch 00020: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 73s 3s/step - loss: 1.3244e-04 - accuracy: 1.0000 - val_loss: 0.3281 - val_accuracy: 0.8921 - lr: 0.0010
# Epoch 21/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8136e-04 - accuracy: 1.0000
# Epoch 00021: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 70s 2s/step - loss: 1.8136e-04 - accuracy: 1.0000 - val_loss: 0.3122 - val_accuracy: 0.8921 - lr: 0.0010
# Epoch 22/100
# 28/28 [==============================] - ETA: 0s - loss: 9.1112e-05 - accuracy: 1.0000
# Epoch 00022: val_accuracy improved from 0.89438 to 0.89663, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 70s 2s/step - loss: 9.1112e-05 - accuracy: 1.0000 - val_loss: 0.3196 - val_accuracy: 0.8966 - lr: 0.0010
# Epoch 23/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3133e-04 - accuracy: 1.0000
# Epoch 00023: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 68s 2s/step - loss: 1.3133e-04 - accuracy: 1.0000 - val_loss: 0.3360 - val_accuracy: 0.8966 - lr: 0.0010
# Epoch 24/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7083e-04 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 67s 2s/step - loss: 1.7083e-04 - accuracy: 1.0000 - val_loss: 0.3427 - val_accuracy: 0.8966 - lr: 0.0010
# Epoch 25/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6952e-04 - accuracy: 1.0000
# Epoch 00025: val_accuracy improved from 0.89663 to 0.89888, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 65s 2s/step - loss: 1.6952e-04 - accuracy: 1.0000 - val_loss: 0.3799 - val_accuracy: 0.8989 - lr: 0.0010
# Epoch 26/100
# 28/28 [==============================] - ETA: 0s - loss: 8.4896e-05 - accuracy: 1.0000
# Epoch 00026: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 66s 2s/step - loss: 8.4896e-05 - accuracy: 1.0000 - val_loss: 0.3837 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 27/100
# 28/28 [==============================] - ETA: 0s - loss: 7.6703e-05 - accuracy: 1.0000
# Epoch 00027: val_accuracy improved from 0.89888 to 0.90112, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 66s 2s/step - loss: 7.6703e-05 - accuracy: 1.0000 - val_loss: 0.3914 - val_accuracy: 0.9011 - lr: 0.0010
# Epoch 28/100
# 28/28 [==============================] - ETA: 0s - loss: 7.2163e-05 - accuracy: 1.0000
# Epoch 00028: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 69s 2s/step - loss: 7.2163e-05 - accuracy: 1.0000 - val_loss: 0.3953 - val_accuracy: 0.8989 - lr: 0.0010
# Epoch 29/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0598e-04 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 64s 2s/step - loss: 1.0598e-04 - accuracy: 1.0000 - val_loss: 0.4381 - val_accuracy: 0.8966 - lr: 0.0010
# Epoch 30/100
# 28/28 [==============================] - ETA: 0s - loss: 6.3180e-05 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 70s 3s/step - loss: 6.3180e-05 - accuracy: 1.0000 - val_loss: 0.4064 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 31/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3968e-04 - accuracy: 1.0000
# Epoch 00031: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 73s 3s/step - loss: 1.3968e-04 - accuracy: 1.0000 - val_loss: 0.6223 - val_accuracy: 0.8831 - lr: 0.0010
# Epoch 32/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1462e-04 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 68s 2s/step - loss: 1.1462e-04 - accuracy: 1.0000 - val_loss: 0.4315 - val_accuracy: 0.8989 - lr: 0.0010
# Epoch 33/100
# 28/28 [==============================] - ETA: 0s - loss: 5.5859e-05 - accuracy: 1.0000
# Epoch 00033: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 67s 2s/step - loss: 5.5859e-05 - accuracy: 1.0000 - val_loss: 0.4270 - val_accuracy: 0.8899 - lr: 0.0010
# Epoch 34/100
# 28/28 [==============================] - ETA: 0s - loss: 9.3630e-05 - accuracy: 1.0000
# Epoch 00034: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 67s 2s/step - loss: 9.3630e-05 - accuracy: 1.0000 - val_loss: 0.4319 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 35/100
# 28/28 [==============================] - ETA: 0s - loss: 6.5661e-05 - accuracy: 1.0000
# Epoch 00035: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 64s 2s/step - loss: 6.5661e-05 - accuracy: 1.0000 - val_loss: 0.4242 - val_accuracy: 0.8989 - lr: 0.0010
# Epoch 36/100
# 28/28 [==============================] - ETA: 0s - loss: 5.5134e-05 - accuracy: 1.0000
# Epoch 00036: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 68s 2s/step - loss: 5.5134e-05 - accuracy: 1.0000 - val_loss: 0.4306 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 37/100
# 28/28 [==============================] - ETA: 0s - loss: 4.8659e-05 - accuracy: 1.0000
# Epoch 00037: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 66s 2s/step - loss: 4.8659e-05 - accuracy: 1.0000 - val_loss: 0.4361 - val_accuracy: 0.8899 - lr: 0.0010
# Epoch 38/100
# 28/28 [==============================] - ETA: 0s - loss: 4.2303e-05 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 72s 3s/step - loss: 4.2303e-05 - accuracy: 1.0000 - val_loss: 0.4276 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 39/100
# 28/28 [==============================] - ETA: 0s - loss: 3.4979e-05 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 68s 2s/step - loss: 3.4979e-05 - accuracy: 1.0000 - val_loss: 0.4299 - val_accuracy: 0.8989 - lr: 0.0010
# Epoch 40/100
# 28/28 [==============================] - ETA: 0s - loss: 4.3232e-05 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 67s 2s/step - loss: 4.3232e-05 - accuracy: 1.0000 - val_loss: 0.4358 - val_accuracy: 0.8921 - lr: 0.0010
# Epoch 41/100
# 28/28 [==============================] - ETA: 0s - loss: 3.6793e-05 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 65s 2s/step - loss: 3.6793e-05 - accuracy: 1.0000 - val_loss: 0.4322 - val_accuracy: 0.8966 - lr: 0.0010
# Epoch 42/100
# 28/28 [==============================] - ETA: 0s - loss: 5.6089e-05 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 64s 2s/step - loss: 5.6089e-05 - accuracy: 1.0000 - val_loss: 0.4563 - val_accuracy: 0.9011 - lr: 0.0010
# Epoch 43/100
# 28/28 [==============================] - ETA: 0s - loss: 4.4980e-05 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 64s 2s/step - loss: 4.4980e-05 - accuracy: 1.0000 - val_loss: 0.4383 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 44/100
# 28/28 [==============================] - ETA: 0s - loss: 3.4117e-05 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 64s 2s/step - loss: 3.4117e-05 - accuracy: 1.0000 - val_loss: 0.4347 - val_accuracy: 0.8921 - lr: 0.0010
# Epoch 45/100
# 28/28 [==============================] - ETA: 0s - loss: 2.6590e-05 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 68s 2s/step - loss: 2.6590e-05 - accuracy: 1.0000 - val_loss: 0.4394 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 46/100
# 28/28 [==============================] - ETA: 0s - loss: 2.4616e-05 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 65s 2s/step - loss: 2.4616e-05 - accuracy: 1.0000 - val_loss: 0.4416 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 47/100
# 28/28 [==============================] - ETA: 0s - loss: 3.9121e-05 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.90112
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 28/28 [==============================] - 62s 2s/step - loss: 3.9121e-05 - accuracy: 1.0000 - val_loss: 0.4488 - val_accuracy: 0.8989 - lr: 0.0010
# Epoch 48/100
# 28/28 [==============================] - ETA: 0s - loss: 2.4247e-05 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 62s 2s/step - loss: 2.4247e-05 - accuracy: 1.0000 - val_loss: 0.4444 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 49/100
# 28/28 [==============================] - ETA: 0s - loss: 4.0408e-05 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 61s 2s/step - loss: 4.0408e-05 - accuracy: 1.0000 - val_loss: 0.4407 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 50/100
# 28/28 [==============================] - ETA: 0s - loss: 7.9606e-05 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 62s 2s/step - loss: 7.9606e-05 - accuracy: 1.0000 - val_loss: 0.4352 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 51/100
# 28/28 [==============================] - ETA: 0s - loss: 3.9988e-05 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 61s 2s/step - loss: 3.9988e-05 - accuracy: 1.0000 - val_loss: 0.4534 - val_accuracy: 0.9011 - lr: 5.0000e-04
# Epoch 52/100
# 28/28 [==============================] - ETA: 0s - loss: 6.3418e-05 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.90112
# 28/28 [==============================] - 63s 2s/step - loss: 6.3418e-05 - accuracy: 1.0000 - val_loss: 0.4367 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 53/100
# 28/28 [==============================] - ETA: 0s - loss: 3.0995e-05 - accuracy: 1.0000
# Epoch 00053: val_accuracy improved from 0.90112 to 0.90337, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 62s 2s/step - loss: 3.0995e-05 - accuracy: 1.0000 - val_loss: 0.4525 - val_accuracy: 0.9034 - lr: 5.0000e-04
# Epoch 54/100
# 28/28 [==============================] - ETA: 0s - loss: 4.1895e-05 - accuracy: 1.0000
# Epoch 00054: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 64s 2s/step - loss: 4.1895e-05 - accuracy: 1.0000 - val_loss: 0.4497 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 55/100
# 28/28 [==============================] - ETA: 0s - loss: 2.3862e-05 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 66s 2s/step - loss: 2.3862e-05 - accuracy: 1.0000 - val_loss: 0.4801 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 56/100
# 28/28 [==============================] - ETA: 0s - loss: 2.7884e-05 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 66s 2s/step - loss: 2.7884e-05 - accuracy: 1.0000 - val_loss: 0.4565 - val_accuracy: 0.9011 - lr: 5.0000e-04
# Epoch 57/100
# 28/28 [==============================] - ETA: 0s - loss: 4.1196e-05 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 62s 2s/step - loss: 4.1196e-05 - accuracy: 1.0000 - val_loss: 0.4558 - val_accuracy: 0.9034 - lr: 5.0000e-04
# Epoch 58/100
# 28/28 [==============================] - ETA: 0s - loss: 3.0838e-05 - accuracy: 1.0000
# Epoch 00058: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 62s 2s/step - loss: 3.0838e-05 - accuracy: 1.0000 - val_loss: 0.4378 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 59/100
# 28/28 [==============================] - ETA: 0s - loss: 2.3790e-05 - accuracy: 1.0000
# Epoch 00059: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 61s 2s/step - loss: 2.3790e-05 - accuracy: 1.0000 - val_loss: 0.4402 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 60/100
# 28/28 [==============================] - ETA: 0s - loss: 3.4354e-05 - accuracy: 1.0000
# Epoch 00060: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 61s 2s/step - loss: 3.4354e-05 - accuracy: 1.0000 - val_loss: 0.4497 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 61/100
# 28/28 [==============================] - ETA: 0s - loss: 5.6098e-05 - accuracy: 1.0000
# Epoch 00061: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 61s 2s/step - loss: 5.6098e-05 - accuracy: 1.0000 - val_loss: 0.4473 - val_accuracy: 0.9011 - lr: 5.0000e-04
# Epoch 62/100
# 28/28 [==============================] - ETA: 0s - loss: 2.8895e-05 - accuracy: 1.0000
# Epoch 00062: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 66s 2s/step - loss: 2.8895e-05 - accuracy: 1.0000 - val_loss: 0.4440 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 63/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8824e-05 - accuracy: 1.0000
# Epoch 00063: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 63s 2s/step - loss: 1.8824e-05 - accuracy: 1.0000 - val_loss: 0.4479 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 64/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8081e-05 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 62s 2s/step - loss: 1.8081e-05 - accuracy: 1.0000 - val_loss: 0.4434 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 65/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1948e-05 - accuracy: 1.0000
# Epoch 00065: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 61s 2s/step - loss: 2.1948e-05 - accuracy: 1.0000 - val_loss: 0.4482 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 66/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1584e-05 - accuracy: 1.0000
# Epoch 00066: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 61s 2s/step - loss: 2.1584e-05 - accuracy: 1.0000 - val_loss: 0.4431 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 67/100
# 28/28 [==============================] - ETA: 0s - loss: 3.0460e-05 - accuracy: 1.0000
# Epoch 00067: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 61s 2s/step - loss: 3.0460e-05 - accuracy: 1.0000 - val_loss: 0.4420 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 68/100
# 28/28 [==============================] - ETA: 0s - loss: 2.4503e-05 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 0.90337
# 28/28 [==============================] - 66s 2s/step - loss: 2.4503e-05 - accuracy: 1.0000 - val_loss: 0.4420 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 69/100
# 28/28 [==============================] - ETA: 0s - loss: 2.7564e-05 - accuracy: 1.0000
# Epoch 00069: val_accuracy improved from 0.90337 to 0.90562, saving model to BiLSTM_V5_2.h5
# 28/28 [==============================] - 66s 2s/step - loss: 2.7564e-05 - accuracy: 1.0000 - val_loss: 0.4596 - val_accuracy: 0.9056 - lr: 5.0000e-04
# Epoch 70/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5607e-05 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 65s 2s/step - loss: 1.5607e-05 - accuracy: 1.0000 - val_loss: 0.4481 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 71/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1586e-05 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 72s 3s/step - loss: 2.1586e-05 - accuracy: 1.0000 - val_loss: 0.4431 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 72/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1143e-05 - accuracy: 1.0000
# Epoch 00072: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 65s 2s/step - loss: 2.1143e-05 - accuracy: 1.0000 - val_loss: 0.4437 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 73/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9486e-05 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 66s 2s/step - loss: 1.9486e-05 - accuracy: 1.0000 - val_loss: 0.4492 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 74/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7516e-05 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 65s 2s/step - loss: 1.7516e-05 - accuracy: 1.0000 - val_loss: 0.4457 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 75/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8743e-05 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 66s 2s/step - loss: 1.8743e-05 - accuracy: 1.0000 - val_loss: 0.4426 - val_accuracy: 0.9011 - lr: 5.0000e-04
# Epoch 76/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3944e-04 - accuracy: 1.0000
# Epoch 00076: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 66s 2s/step - loss: 1.3944e-04 - accuracy: 1.0000 - val_loss: 1.9552 - val_accuracy: 0.6742 - lr: 5.0000e-04
# Epoch 77/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0052e-04 - accuracy: 1.0000
# Epoch 00077: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 65s 2s/step - loss: 2.0052e-04 - accuracy: 1.0000 - val_loss: 2.2249 - val_accuracy: 0.6629 - lr: 5.0000e-04
# Epoch 78/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0231e-04 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 62s 2s/step - loss: 1.0231e-04 - accuracy: 1.0000 - val_loss: 0.4353 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 79/100
# 28/28 [==============================] - ETA: 0s - loss: 8.2711e-05 - accuracy: 1.0000
# Epoch 00079: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 65s 2s/step - loss: 8.2711e-05 - accuracy: 1.0000 - val_loss: 0.4734 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 80/100
# 28/28 [==============================] - ETA: 0s - loss: 3.4916e-05 - accuracy: 1.0000
# Epoch 00080: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 65s 2s/step - loss: 3.4916e-05 - accuracy: 1.0000 - val_loss: 0.4955 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 81/100
# 28/28 [==============================] - ETA: 0s - loss: 3.4422e-05 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 61s 2s/step - loss: 3.4422e-05 - accuracy: 1.0000 - val_loss: 0.4621 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 82/100
# 28/28 [==============================] - ETA: 0s - loss: 2.7947e-05 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 61s 2s/step - loss: 2.7947e-05 - accuracy: 1.0000 - val_loss: 0.4522 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 83/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1541e-05 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 67s 2s/step - loss: 2.1541e-05 - accuracy: 1.0000 - val_loss: 0.4528 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 84/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0950e-05 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 66s 2s/step - loss: 2.0950e-05 - accuracy: 1.0000 - val_loss: 0.4518 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 85/100
# 28/28 [==============================] - ETA: 0s - loss: 2.2249e-05 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 62s 2s/step - loss: 2.2249e-05 - accuracy: 1.0000 - val_loss: 0.4503 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 86/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7521e-05 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 61s 2s/step - loss: 1.7521e-05 - accuracy: 1.0000 - val_loss: 0.4518 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 87/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5561e-05 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 61s 2s/step - loss: 1.5561e-05 - accuracy: 1.0000 - val_loss: 0.4521 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 88/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0240e-05 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 62s 2s/step - loss: 2.0240e-05 - accuracy: 1.0000 - val_loss: 0.4572 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 89/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9296e-05 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.90562
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 28/28 [==============================] - 62s 2s/step - loss: 1.9296e-05 - accuracy: 1.0000 - val_loss: 0.4548 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 90/100
# 28/28 [==============================] - ETA: 0s - loss: 4.1556e-05 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 67s 2s/step - loss: 4.1556e-05 - accuracy: 1.0000 - val_loss: 0.4533 - val_accuracy: 0.8944 - lr: 2.5000e-04
# Epoch 91/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2904e-05 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 66s 2s/step - loss: 1.2904e-05 - accuracy: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.8989 - lr: 2.5000e-04
# Epoch 92/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6983e-05 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 60s 2s/step - loss: 1.6983e-05 - accuracy: 1.0000 - val_loss: 0.4517 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 93/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1001e-05 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 62s 2s/step - loss: 2.1001e-05 - accuracy: 1.0000 - val_loss: 0.4524 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 94/100
# 28/28 [==============================] - ETA: 0s - loss: 5.1275e-05 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 61s 2s/step - loss: 5.1275e-05 - accuracy: 1.0000 - val_loss: 0.4777 - val_accuracy: 0.8989 - lr: 2.5000e-04
# Epoch 95/100
# 28/28 [==============================] - ETA: 0s - loss: 4.3223e-05 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 62s 2s/step - loss: 4.3223e-05 - accuracy: 1.0000 - val_loss: 0.4696 - val_accuracy: 0.8989 - lr: 2.5000e-04
# Epoch 96/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7024e-05 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 63s 2s/step - loss: 1.7024e-05 - accuracy: 1.0000 - val_loss: 0.4732 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 97/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9959e-05 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 63s 2s/step - loss: 1.9959e-05 - accuracy: 1.0000 - val_loss: 0.4568 - val_accuracy: 0.8944 - lr: 2.5000e-04
# Epoch 98/100
# 28/28 [==============================] - ETA: 0s - loss: 1.4144e-05 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 63s 2s/step - loss: 1.4144e-05 - accuracy: 1.0000 - val_loss: 0.4555 - val_accuracy: 0.8989 - lr: 2.5000e-04
# Epoch 99/100
# 28/28 [==============================] - ETA: 0s - loss: 3.6084e-05 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 63s 2s/step - loss: 3.6084e-05 - accuracy: 1.0000 - val_loss: 0.4742 - val_accuracy: 0.9034 - lr: 2.5000e-04
# Epoch 100/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0984e-05 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.90562
# 28/28 [==============================] - 63s 2s/step - loss: 1.0984e-05 - accuracy: 1.0000 - val_loss: 0.4674 - val_accuracy: 0.9011 - lr: 2.5000e-04

# %%
# 可视化训练过程中，训练集与验证集的损失和精度
plt.figure(figsize=(16,8))
plt.subplot(121)
plt.plot(history.history['loss'],label = 'train_loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()

plt.subplot(122)
plt.plot(history.history['accuracy'],label = 'train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
# 使用模型得到预测结果
model = load_model('BiLSTM_V5_2.h5')
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
print('在80%训练集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1)), recall_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary'), f1_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary')))
print('在20%测试集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1)), recall_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary'), f1_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary')))
# Out:
# 在80%训练集上, accuracy: 1.0% 召回率:  1.0, f1:  1.0
# 在20%测试集上, accuracy: 0.9056% 召回率: 0.8828451882845189, f1: 0.9094827586206897

# %%
# 绘制混淆矩阵
plt.figure(figsize=(16,8))
plt.subplot(121)
matrix = confusion_matrix(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Train confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.subplot(122)
matrix = confusion_matrix(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Test confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.show()
