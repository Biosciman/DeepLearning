# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, ReLU, Bidirectional,BatchNormalization, Embedding, Conv1D, MaxPool1D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] =False
plt.rcParams.update({"font.size":20})
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, f1_score, recall_score

# %%
negative = pd.read_csv('data/Negative.txt', header = None, index_col=None) 
negative = negative.drop_duplicates()
negative['label'] = 0
positive = pd.read_csv('data/Positive.txt', header = None, index_col=None) 
positive = positive.drop_duplicates()
positive['label'] = 1
# negative[negative.isnull().values==True] # 判断是否存在缺失值

# %%
data = pd.concat([negative, positive], axis=0).reset_index().iloc[:, 1:]
data = data.dropna()

# %%
x_data = data.iloc[:, :-1]
y_data = data.loc[:, 'label']
# 类别均衡化
model_smote = SMOTE()  
x_resampled, y_resampled = model_smote.fit_resample(x_data,y_data)

# %%
# 划分训练数据为80%训练集和20%的验证集
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=7, shuffle=True)

# %%
# # 重置数据维度
# print(x_train.shape)
# x_train = x_train.reshape(-1,1,x_train.shape[-1])
# x_test = x_test.reshape(-1,1,x_test.shape[-1])
# print(x_train.shape)
# Out:
# (1777, 2000)
# (1777, 1, 2000)

# %%
# 对类别数据进行onehot编码
print(y_train.shape)
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)
print(y_train.shape)
# Out:
# (1777,)
# (1777, 2)

# %%
# 构建网络
model = Sequential()
model.add(Embedding(input_dim=21, input_length=2000, output_dim=128))
model.add(Conv1D(128,16, activation='relu'))
model.add(Conv1D(64,16, activation='relu'))
model.add(MaxPool1D(pool_size=5,strides=5))

model.add(Bidirectional(LSTM(units=64, return_sequences=True, activation='relu')))
model.add(BatchNormalization())
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())
model.add(Dense(2, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 2000, 128)         2688
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1985, 128)         262272
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 1970, 64)          131136
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 394, 64)           0
# _________________________________________________________________
# bidirectional_8 (Bidirection (None, 394, 128)          66048
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 394, 128)          512
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, 128)               98816
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 128)               512
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 562,242
# Trainable params: 561,730
# Non-trainable params: 512
# _________________________________________________________________
# (None, 2)

# %%
# 训练网络
epochs = 100 # 训练周期
batch_size = 64 # 批次大小 
# 监视网络的训练，并将在验证集上取得最优结果的网络权重保留下来
checkpoint = ModelCheckpoint("BiLSTM_V5_1.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max') 
# 监视网络的训练，并对学习率进行衰减处理
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=20, verbose=1)
callbacks_list = [checkpoint, reduce_lr] # 监视列表 
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) # 编译网络
# 开始训练，直接使用30%的验证集，在训练过程中测试网络
history = model.fit(x_train, y_train, callbacks=callbacks_list, epochs=epochs, batch_size=batch_size, verbose=1,validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 28/28 [==============================] - ETA: 0s - loss: 0.3965 - accuracy: 0.8323
# Epoch 00001: val_accuracy improved from -inf to 0.84944, saving model to BiLSTM_V5_1.h5
# 28/28 [==============================] - 61s 2s/step - loss: 0.3965 - accuracy: 0.8323 - val_loss: 0.6635 - val_accuracy: 0.8494 - lr: 0.0010
# Epoch 2/100
# 28/28 [==============================] - ETA: 0s - loss: 0.2311 - accuracy: 0.9139
# Epoch 00002: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 59s 2s/step - loss: 0.2311 - accuracy: 0.9139 - val_loss: 0.6693 - val_accuracy: 0.6989 - lr: 0.0010
# Epoch 3/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0922 - accuracy: 0.9724
# Epoch 00003: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 62s 2s/step - loss: 0.0922 - accuracy: 0.9724 - val_loss: 0.6777 - val_accuracy: 0.4674 - lr: 0.0010
# Epoch 4/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9814
# Epoch 00004: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 63s 2s/step - loss: 0.0516 - accuracy: 0.9814 - val_loss: 0.6208 - val_accuracy: 0.7573 - lr: 0.0010
# Epoch 5/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0291 - accuracy: 0.9921
# Epoch 00005: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 61s 2s/step - loss: 0.0291 - accuracy: 0.9921 - val_loss: 0.6673 - val_accuracy: 0.4787 - lr: 0.0010
# Epoch 6/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9994
# Epoch 00006: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 62s 2s/step - loss: 0.0113 - accuracy: 0.9994 - val_loss: 0.6408 - val_accuracy: 0.5169 - lr: 0.0010
# Epoch 7/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9994
# Epoch 00007: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 62s 2s/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.7089 - val_accuracy: 0.4764 - lr: 0.0010
# Epoch 8/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00008: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 61s 2s/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.6830 - val_accuracy: 0.5416 - lr: 0.0010
# Epoch 9/100
# 28/28 [==============================] - ETA: 0s - loss: 6.9830e-04 - accuracy: 1.0000
# Epoch 00009: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 61s 2s/step - loss: 6.9830e-04 - accuracy: 1.0000 - val_loss: 0.5959 - val_accuracy: 0.6090 - lr: 0.0010
# Epoch 10/100
# 28/28 [==============================] - ETA: 0s - loss: 6.8873e-04 - accuracy: 1.0000
# Epoch 00010: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 61s 2s/step - loss: 6.8873e-04 - accuracy: 1.0000 - val_loss: 0.6417 - val_accuracy: 0.6067 - lr: 0.0010
# Epoch 11/100
# 28/28 [==============================] - ETA: 0s - loss: 3.5628e-04 - accuracy: 1.0000
# Epoch 00011: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 60s 2s/step - loss: 3.5628e-04 - accuracy: 1.0000 - val_loss: 0.5304 - val_accuracy: 0.7146 - lr: 0.0010
# Epoch 12/100
# 28/28 [==============================] - ETA: 0s - loss: 3.8143e-04 - accuracy: 1.0000
# Epoch 00012: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 60s 2s/step - loss: 3.8143e-04 - accuracy: 1.0000 - val_loss: 0.5809 - val_accuracy: 0.6989 - lr: 0.0010
# Epoch 13/100
# 28/28 [==============================] - ETA: 0s - loss: 3.9845e-04 - accuracy: 1.0000
# Epoch 00013: val_accuracy did not improve from 0.84944
# 28/28 [==============================] - 60s 2s/step - loss: 3.9845e-04 - accuracy: 1.0000 - val_loss: 0.5843 - val_accuracy: 0.7124 - lr: 0.0010
# Epoch 14/100
# 28/28 [==============================] - ETA: 0s - loss: 2.5155e-04 - accuracy: 1.0000
# Epoch 00014: val_accuracy improved from 0.84944 to 0.85393, saving model to BiLSTM_V5_1.h5
# 28/28 [==============================] - 61s 2s/step - loss: 2.5155e-04 - accuracy: 1.0000 - val_loss: 0.3890 - val_accuracy: 0.8539 - lr: 0.0010
# Epoch 15/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7724e-04 - accuracy: 1.0000
# Epoch 00015: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 63s 2s/step - loss: 1.7724e-04 - accuracy: 1.0000 - val_loss: 0.4367 - val_accuracy: 0.8360 - lr: 0.0010
# Epoch 16/100
# 28/28 [==============================] - ETA: 0s - loss: 2.4470e-04 - accuracy: 1.0000
# Epoch 00016: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 69s 2s/step - loss: 2.4470e-04 - accuracy: 1.0000 - val_loss: 0.5931 - val_accuracy: 0.7663 - lr: 0.0010
# Epoch 17/100
# 28/28 [==============================] - ETA: 0s - loss: 2.9188e-04 - accuracy: 1.0000
# Epoch 00017: val_accuracy improved from 0.85393 to 0.86742, saving model to BiLSTM_V5_1.h5
# 28/28 [==============================] - 60s 2s/step - loss: 2.9188e-04 - accuracy: 1.0000 - val_loss: 0.4156 - val_accuracy: 0.8674 - lr: 0.0010
# Epoch 18/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5933e-04 - accuracy: 1.0000
# Epoch 00018: val_accuracy improved from 0.86742 to 0.87191, saving model to BiLSTM_V5_1.h5
# 28/28 [==============================] - 63s 2s/step - loss: 1.5933e-04 - accuracy: 1.0000 - val_loss: 0.4216 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 19/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1625e-04 - accuracy: 1.0000
# Epoch 00019: val_accuracy improved from 0.87191 to 0.87865, saving model to BiLSTM_V5_1.h5
# 28/28 [==============================] - 62s 2s/step - loss: 2.1625e-04 - accuracy: 1.0000 - val_loss: 0.4081 - val_accuracy: 0.8787 - lr: 0.0010
# Epoch 20/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1593e-04 - accuracy: 1.0000
# Epoch 00020: val_accuracy did not improve from 0.87865
# 28/28 [==============================] - 63s 2s/step - loss: 2.1593e-04 - accuracy: 1.0000 - val_loss: 0.4470 - val_accuracy: 0.8787 - lr: 0.0010
# Epoch 21/100
# 28/28 [==============================] - ETA: 0s - loss: 3.0947e-04 - accuracy: 1.0000
# Epoch 00021: val_accuracy did not improve from 0.87865
# 28/28 [==============================] - 67s 2s/step - loss: 3.0947e-04 - accuracy: 1.0000 - val_loss: 1.1309 - val_accuracy: 0.7258 - lr: 0.0010
# Epoch 22/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1930e-04 - accuracy: 1.0000
# Epoch 00022: val_accuracy did not improve from 0.87865
# 28/28 [==============================] - 61s 2s/step - loss: 1.1930e-04 - accuracy: 1.0000 - val_loss: 0.4865 - val_accuracy: 0.8787 - lr: 0.0010
# Epoch 23/100
# 28/28 [==============================] - ETA: 0s - loss: 7.8045e-05 - accuracy: 1.0000
# Epoch 00023: val_accuracy improved from 0.87865 to 0.88989, saving model to BiLSTM_V5_1.h5
# 28/28 [==============================] - 65s 2s/step - loss: 7.8045e-05 - accuracy: 1.0000 - val_loss: 0.4304 - val_accuracy: 0.8899 - lr: 0.0010
# Epoch
val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 63s 2s/step - loss: 5.9921e-05 - accuracy: 1.0000 - val_loss: 0.5339 - val_accuracy: 0.8854 - lr: 0.0010
# Epoch 38/100
# 28/28 [==============================] - ETA: 0s - loss: 4.7770e-05 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 68s 2s/step - loss: 4.7770e-05 - accuracy: 1.0000 - val_loss: 0.5094 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 39/100
# 28/28 [==============================] - ETA: 0s - loss: 5.5235e-05 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 71s 3s/step - loss: 5.5235e-05 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.8921 - lr: 0.0010
# Epoch 40/100
# 28/28 [==============================] - ETA: 0s - loss: 4.0023e-05 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 72s 3s/step - loss: 4.0023e-05 - accuracy: 1.0000 - val_loss: 0.5124 - val_accuracy: 0.8921 - lr: 0.0010
# Epoch 41/100
# 28/28 [==============================] - ETA: 0s - loss: 5.2227e-05 - accuracy: 1.0000
# Epoch 00041: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 66s 2s/step - loss: 5.2227e-05 - accuracy: 1.0000 - val_loss: 0.5125 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 42/100
# 28/28 [==============================] - ETA: 0s - loss: 6.4453e-05 - accuracy: 1.0000
# Epoch 00042: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 66s 2s/step - loss: 6.4453e-05 - accuracy: 1.0000 - val_loss: 0.5196 - val_accuracy: 0.8899 - lr: 0.0010
# Epoch 43/100
# 28/28 [==============================] - ETA: 0s - loss: 3.6063e-05 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 69s 2s/step - loss: 3.6063e-05 - accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 44/100
# 28/28 [==============================] - ETA: 0s - loss: 3.3439e-05 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 68s 2s/step - loss: 3.3439e-05 - accuracy: 1.0000 - val_loss: 0.5196 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 45/100
# 28/28 [==============================] - ETA: 0s - loss: 3.5865e-05 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.89438
# 28/28 [==============================] - 65s 2s/step - loss: 3.5865e-05 - accuracy: 1.0000 - val_loss: 0.5338 - val_accuracy: 0.8876 - lr: 0.0010
# Epoch 46/100
# 28/28 [==============================] - ETA: 0s - loss: 3.8951e-05 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.89438
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 28/28 [==============================] - 61s 2s/step - loss: 3.8951e-05 - accuracy: 1.0000 - val_loss: 0.5293 - val_accuracy: 0.8921 - lr: 0.0010
# Epoch 47/100
# 28/28 [==============================] - ETA: 0s - loss: 3.5778e-05 - accuracy: 1.0000
# Epoch 00047: val_accuracy improved from 0.89438 to 0.89663, saving model to BiLSTM_V5_1.h5
# 28/28 [==============================] - 61s 2s/step - loss: 3.5778e-05 - accuracy: 1.0000 - val_loss: 0.5213 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 48/100
# 28/28 [==============================] - ETA: 0s - loss: 3.3510e-05 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 71s 3s/step - loss: 3.3510e-05 - accuracy: 1.0000 - val_loss: 0.5272 - val_accuracy: 0.8899 - lr: 5.0000e-04
# Epoch 49/100
# 28/28 [==============================] - ETA: 0s - loss: 3.1377e-05 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 69s 2s/step - loss: 3.1377e-05 - accuracy: 1.0000 - val_loss: 0.5289 - val_accuracy: 0.8899 - lr: 5.0000e-04
# Epoch 50/100
# 28/28 [==============================] - ETA: 0s - loss: 3.8946e-05 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 67s 2s/step - loss: 3.8946e-05 - accuracy: 1.0000 - val_loss: 0.5216 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 51/100
# 28/28 [==============================] - ETA: 0s - loss: 5.1088e-05 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 67s 2s/step - loss: 5.1088e-05 - accuracy: 1.0000 - val_loss: 0.5358 - val_accuracy: 0.8876 - lr: 5.0000e-04
# Epoch 52/100
# 28/28 [==============================] - ETA: 0s - loss: 3.4098e-05 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 67s 2s/step - loss: 3.4098e-05 - accuracy: 1.0000 - val_loss: 0.5525 - val_accuracy: 0.8876 - lr: 5.0000e-04
# Epoch 53/100
# 28/28 [==============================] - ETA: 0s - loss: 2.9162e-05 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 72s 3s/step - loss: 2.9162e-05 - accuracy: 1.0000 - val_loss: 0.5309 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 54/100
# 28/28 [==============================] - ETA: 0s - loss: 4.1539e-05 - accuracy: 1.0000
# Epoch 00054: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 69s 2s/step - loss: 4.1539e-05 - accuracy: 1.0000 - val_loss: 0.5343 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 55/100
# 28/28 [==============================] - ETA: 0s - loss: 3.7730e-05 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 64s 2s/step - loss: 3.7730e-05 - accuracy: 1.0000 - val_loss: 0.5302 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 56/100
# 28/28 [==============================] - ETA: 0s - loss: 2.7253e-05 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 65s 2s/step - loss: 2.7253e-05 - accuracy: 1.0000 - val_loss: 0.5466 - val_accuracy: 0.8876 - lr: 5.0000e-04
# Epoch 57/100
# 28/28 [==============================] - ETA: 0s - loss: 3.4110e-05 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 66s 2s/step - loss: 3.4110e-05 - accuracy: 1.0000 - val_loss: 0.5331 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 58/100
# 28/28 [==============================] - ETA: 0s - loss: 2.8958e-05 - accuracy: 1.0000
# Epoch 00058: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 70s 3s/step - loss: 2.8958e-05 - accuracy: 1.0000 - val_loss: 0.5381 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 59/100
# 28/28 [==============================] - ETA: 0s - loss: 2.2578e-05 - accuracy: 1.0000
# Epoch 00059: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 68s 2s/step - loss: 2.2578e-05 - accuracy: 1.0000 - val_loss: 0.5390 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 60/100
# 28/28 [==============================] - ETA: 0s - loss: 4.3021e-05 - accuracy: 1.0000
# Epoch 00060: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 64s 2s/step - loss: 4.3021e-05 - accuracy: 1.0000 - val_loss: 0.5448 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 61/100
# 28/28 [==============================] - ETA: 0s - loss: 3.5248e-05 - accuracy: 1.0000
# Epoch 00061: val_accuracy did not improve from 0.89663
# 28/28 [==============================] - 65s 2s/step - loss: 3.5248e-05 - accuracy: 1.0000 - val_loss: 0.5369 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 62/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0696e-05 - accuracy: 1.0000
# Epoch 00062: val_accuracy improved from 0.89663 to 0.89888, saving model to BiLSTM_V5_1.h5
# 28/28 [==============================] - 64s 2s/step - loss: 2.0696e-05 - accuracy: 1.0000 - val_loss: 0.5287 - val_accuracy: 0.8989 - lr: 5.0000e-04
# Epoch 63/100
# 28/28 [==============================] - ETA: 0s - loss: 3.3712e-05 - accuracy: 1.0000
# Epoch 00063: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 66s 2s/step - loss: 3.3712e-05 - accuracy: 1.0000 - val_loss: 0.5395 - val_accuracy: 0.8899 - lr: 5.0000e-04
# Epoch 64/100
# 28/28 [==============================] - ETA: 0s - loss: 2.4354e-05 - accuracy: 1.0000
# Epoch 00064: val_accuracy did not improve from 0.89888
# 28/28 [==============================] -
val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 63s 2s/step - loss: 2.2221e-05 - accuracy: 1.0000 - val_loss: 0.5696 - val_accuracy: 0.8876 - lr: 5.0000e-04
# Epoch 81/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9613e-05 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 68s 2s/step - loss: 1.9613e-05 - accuracy: 1.0000 - val_loss: 0.5575 - val_accuracy: 0.8944 - lr: 5.0000e-04
# Epoch 82/100
# 28/28 [==============================] - ETA: 0s - loss: 2.8884e-05 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.89888
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 28/28 [==============================] - 65s 2s/step - loss: 2.8884e-05 - accuracy: 1.0000 - val_loss: 0.5526 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 83/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8067e-05 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 1988s 71s/step - loss: 1.8067e-05 - accuracy: 1.0000 - val_loss: 0.5528 - val_accuracy: 0.8989 - lr: 2.5000e-04
# Epoch 84/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8997e-05 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 60s 2s/step - loss: 1.8997e-05 - accuracy: 1.0000 - val_loss: 0.5543 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 85/100
# 28/28 [==============================] - ETA: 0s - loss: 3.9222e-05 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 64s 2s/step - loss: 3.9222e-05 - accuracy: 1.0000 - val_loss: 0.5535 - val_accuracy: 0.8989 - lr: 2.5000e-04
# Epoch 86/100
# 28/28 [==============================] - ETA: 0s - loss: 3.2935e-05 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 66s 2s/step - loss: 3.2935e-05 - accuracy: 1.0000 - val_loss: 0.5510 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 87/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5945e-05 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 63s 2s/step - loss: 1.5945e-05 - accuracy: 1.0000 - val_loss: 0.5555 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 88/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6665e-05 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 90s 3s/step - loss: 1.6665e-05 - accuracy: 1.0000 - val_loss: 0.5589 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 89/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5886e-05 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 113s 4s/step - loss: 1.5886e-05 - accuracy: 1.0000 - val_loss: 0.5613 - val_accuracy: 0.8921 - lr: 2.5000e-04
# Epoch 90/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2435e-05 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 109s 4s/step - loss: 1.2435e-05 - accuracy: 1.0000 - val_loss: 0.5631 - val_accuracy: 0.8921 - lr: 2.5000e-04
# Epoch 91/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1662e-05 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 109s 4s/step - loss: 1.1662e-05 - accuracy: 1.0000 - val_loss: 0.5619 - val_accuracy: 0.8944 - lr: 2.5000e-04
# Epoch 92/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6402e-05 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 108s 4s/step - loss: 1.6402e-05 - accuracy: 1.0000 - val_loss: 0.5623 - val_accuracy: 0.8944 - lr: 2.5000e-04
# Epoch 93/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0939e-05 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 109s 4s/step - loss: 2.0939e-05 - accuracy: 1.0000 - val_loss: 0.5595 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 94/100
# 28/28 [==============================] - ETA: 0s - loss: 3.0085e-05 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 108s 4s/step - loss: 3.0085e-05 - accuracy: 1.0000 - val_loss: 0.5690 - val_accuracy: 0.8921 - lr: 2.5000e-04
# Epoch 95/100
# 28/28 [==============================] - ETA: 0s - loss: 2.2154e-05 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 107s 4s/step - loss: 2.2154e-05 - accuracy: 1.0000 - val_loss: 0.5784 - val_accuracy: 0.8899 - lr: 2.5000e-04
# Epoch 96/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5948e-05 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 107s 4s/step - loss: 1.5948e-05 - accuracy: 1.0000 - val_loss: 0.5723 - val_accuracy: 0.8921 - lr: 2.5000e-04
# Epoch 97/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6408e-05 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 109s 4s/step - loss: 1.6408e-05 - accuracy: 1.0000 - val_loss: 0.5678 - val_accuracy: 0.8944 - lr: 2.5000e-04
# Epoch 98/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8580e-05 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 107s 4s/step - loss: 1.8580e-05 - accuracy: 1.0000 - val_loss: 0.5662 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 99/100
# 28/28 [==============================] - ETA: 0s - loss: 2.7382e-05 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 107s 4s/step - loss: 2.7382e-05 - accuracy: 1.0000 - val_loss: 0.5645 - val_accuracy: 0.8966 - lr: 2.5000e-04
# Epoch 100/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5161e-05 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.89888
# 28/28 [==============================] - 110s 4s/step - loss: 1.5161e-05 - accuracy: 1.0000 - val_loss: 0.5606 - val_accuracy: 0.8989 - lr: 2.5000e-04

# %%
# 可视化训练过程中，训练集与验证集的损失和精度
plt.figure(figsize=(16,8))
plt.subplot(121)
plt.plot(history.history['loss'],label = 'train_loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()

plt.subplot(122)
plt.plot(history.history['accuracy'],label = 'train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
# 使用模型得到预测结果
model = load_model('BiLSTM_V5_1.h5')
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
print('在80%训练集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1)), recall_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary'), f1_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary')))
print('在20%测试集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1)), recall_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary'), f1_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary')))
# Out:
# 在80%训练集上, accuracy: 1.0% 召回率:  1.0, f1:  1.0
# 在20%测试集上, accuracy: 0.8989% 召回率: 0.9037656903765691, f1: 0.9056603773584906

# %%
# 绘制混淆矩阵
plt.figure(figsize=(16,8))
plt.subplot(121)
matrix = confusion_matrix(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Train confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.subplot(122)
matrix = confusion_matrix(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Test confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.show()
