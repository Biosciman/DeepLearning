# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, ReLU, Bidirectional,BatchNormalization, Embedding, Conv1D, MaxPool1D, Flatten
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] =False
plt.rcParams.update({"font.size":20})
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, f1_score, recall_score

# %%
negative = pd.read_csv('data/Negative.txt', header = None, index_col=None) 
negative = negative.drop_duplicates()
negative['label'] = 0
positive = pd.read_csv('data/Positive.txt', header = None, index_col=None) 
positive = positive.drop_duplicates()
positive['label'] = 1
# negative[negative.isnull().values==True] # 判断是否存在缺失值

# %%
data = pd.concat([negative, positive], axis=0).reset_index().iloc[:, 1:]
data = data.dropna()

# %%
x_data = data.iloc[:, :-1]
y_data = data.loc[:, 'label']
# 类别均衡化
model_smote = SMOTE()  
x_resampled, y_resampled = model_smote.fit_resample(x_data,y_data)

# %%
# 划分训练数据为80%训练集和20%的验证集
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=7, shuffle=True)

# %%
# # 重置数据维度
# print(x_train.shape)
# x_train = x_train.reshape(-1,1,x_train.shape[-1])
# x_test = x_test.reshape(-1,1,x_test.shape[-1])
# print(x_train.shape)
# Out:
# (1777, 2000)
# (1777, 1, 2000)

# %%
# 对类别数据进行onehot编码
print(y_train.shape)
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)
print(y_train.shape)
# Out:
# (1777,)
# (1777, 2)

# %%
# 构建网络
model = Sequential()
model.add(Embedding(input_dim=21, input_length=2000, output_dim=128))
model.add(Conv1D(128,8, activation='relu'))
model.add(Conv1D(64,1, activation='relu'))
model.add(Conv1D(64,3, activation='relu'))
model.add(Conv1D(128,1, activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPool1D(pool_size=5,strides=5))

model.add(Bidirectional(LSTM(units=64, return_sequences=True, activation='relu')))
model.add(BatchNormalization())
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())
model.add(Dense(2, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 2000, 128)         2688
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1993, 128)         131200
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1993, 64)          8256
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1991, 64)          12352
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1991, 128)         8320
# _________________________________________________________________
# dropout (Dropout)            (None, 1991, 128)         0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 398, 128)          0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 398, 128)          98816
# _________________________________________________________________
# batch_normalization (BatchNo (None, 398, 128)          512
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               98816
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 2)                 258
# =================================================================
# Total params: 361,730
# Trainable params: 361,218
# Non-trainable params: 512
# _________________________________________________________________

# %%
# 训练网络
epochs = 100 # 训练周期
batch_size = 64 # 批次大小 
# 监视网络的训练，并将在验证集上取得最优结果的网络权重保留下来
checkpoint = ModelCheckpoint("BiLSTM_V11_1.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max') 
# 监视网络的训练，并对学习率进行衰减处理
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=20, verbose=1)
callbacks_list = [checkpoint, reduce_lr] # 监视列表 
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) # 编译网络
# 开始训练，直接使用30%的验证集，在训练过程中测试网络
history = model.fit(x_train, y_train, callbacks=callbacks_list, epochs=epochs, batch_size=batch_size, verbose=1,validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 28/28 [==============================] - ETA: 0s - loss: 0.4383 - accuracy: 0.8036
# Epoch 00001: val_accuracy improved from -inf to 0.53708, saving model to BiLSTM_V11_1.h5
# 28/28 [==============================] - 111s 4s/step - loss: 0.4383 - accuracy: 0.8036 - val_loss: 0.6857 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 2/100
# 28/28 [==============================] - ETA: 0s - loss: 0.3115 - accuracy: 0.8762
# Epoch 00002: val_accuracy did not improve from 0.53708
# 28/28 [==============================] - 101s 4s/step - loss: 0.3115 - accuracy: 0.8762 - val_loss: 0.6845 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 3/100
# 28/28 [==============================] - ETA: 0s - loss: 0.2760 - accuracy: 0.8863
# Epoch 00003: val_accuracy did not improve from 0.53708
# 28/28 [==============================] - 101s 4s/step - loss: 0.2760 - accuracy: 0.8863 - val_loss: 0.6801 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 4/100
# 28/28 [==============================] - ETA: 0s - loss: 0.1884 - accuracy: 0.9280
# Epoch 00004: val_accuracy did not improve from 0.53708
# 28/28 [==============================] - 102s 4s/step - loss: 0.1884 - accuracy: 0.9280 - val_loss: 0.6772 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 5/100
# 28/28 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9488
# Epoch 00005: val_accuracy improved from 0.53708 to 0.80000, saving model to BiLSTM_V11_1.h5
# 28/28 [==============================] - 95s 3s/step - loss: 0.1396 - accuracy: 0.9488 - val_loss: 0.6692 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 6/100
# 28/28 [==============================] - ETA: 0s - loss: 0.1237 - accuracy: 0.9595
# Epoch 00006: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 79s 3s/step - loss: 0.1237 - accuracy: 0.9595 - val_loss: 0.7092 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 7/100
# 28/28 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9567
# Epoch 00007: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 70s 2s/step - loss: 0.1114 - accuracy: 0.9567 - val_loss: 0.7238 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 8/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9713
# Epoch 00008: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 70s 2s/step - loss: 0.0723 - accuracy: 0.9713 - val_loss: 0.9206 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 9/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0668 - accuracy: 0.9758
# Epoch 00009: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 69s 2s/step - loss: 0.0668 - accuracy: 0.9758 - val_loss: 0.7955 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 10/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0396 - accuracy: 0.9899
# Epoch 00010: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 76s 3s/step - loss: 0.0396 - accuracy: 0.9899 - val_loss: 1.1823 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 11/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9949
# Epoch 00011: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 70s 2s/step - loss: 0.0224 - accuracy: 0.9949 - val_loss: 1.3508 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 12/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9966
# Epoch 00012: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 69s 2s/step - loss: 0.0128 - accuracy: 0.9966 - val_loss: 1.2069 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 13/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9994
# Epoch 00013: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 70s 2s/step - loss: 0.0063 - accuracy: 0.9994 - val_loss: 1.3493 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 14/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9977
# Epoch 00014: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 70s 2s/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 1.0600 - val_accuracy: 0.4809 - lr: 0.0010
# Epoch 15/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9932
# Epoch 00015: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 71s 3s/step - loss: 0.0173 - accuracy: 0.9932 - val_loss: 0.9790 - val_accuracy: 0.5348 - lr: 0.0010
# Epoch 16/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9921
# Epoch 00016: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 69s 2s/step - loss: 0.0275 - accuracy: 0.9921 - val_loss: 1.2478 - val_accuracy: 0.4899 - lr: 0.0010
# Epoch 17/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9916
# Epoch 00017: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 70s 3s/step - loss: 0.0232 - accuracy: 0.9916 - val_loss: 0.8743 - val_accuracy: 0.6202 - lr: 0.0010
# Epoch 18/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9944
# Epoch 00018: val_accuracy did not improve from 0.80000
# 28/28 [==============================] - 70s 3s/step - loss: 0.0182 - accuracy: 0.9944 - val_loss: 1.4852 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 19/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9944
# Epoch 00019: val_accuracy improved from 0.80000 to 0.83596, saving model to BiLSTM_V11_1.h5
# 28/28 [==============================] - 71s 3s/step - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.3431 - val_accuracy: 0.8360 - lr: 0.0010
# Epoch 20/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9944
# Epoch 00020: val_accuracy improved from 0.83596 to 0.87416, saving model to BiLSTM_V11_1.h5
# 28/28 [==============================] - 70s 3s/step - loss: 0.0202 - accuracy: 0.9944 - val_loss: 0.3518 - val_accuracy: 0.8742 - lr: 0.0010
# Epoch 21/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9859
# Epoch 00021: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0349 - accuracy: 0.9859 - val_loss: 0.4246 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 22/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9854
# Epoch 00022: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0446 - accuracy: 0.9854 - val_loss: 2.4227 - val_accuracy: 0.4809 - lr: 0.0010
# Epoch 23/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9921
# Epoch 00023: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0238 - accuracy: 0.9921 - val_loss: 0.7660 - val_accuracy: 0.7865 - lr: 0.0010
# Epoch 24/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9887
# Epoch 00024: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 70s 2s/step - loss: 0.0309 - accuracy: 0.9887 - val_loss: 0.4325 - val_accuracy: 0.8404 - lr: 0.0010
# Epoch 25/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9887
# Epoch 00025: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 71s 3s/step - loss: 0.0309 - accuracy: 0.9887 - val_loss: 0.5089 - val_accuracy: 0.8562 - lr: 0.0010
# Epoch 26/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0143 - accuracy: 0.9955
# Epoch 00026: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 70s 2s/step - loss: 0.0143 - accuracy: 0.9955 - val_loss: 1.5526 - val_accuracy: 0.7461 - lr: 0.0010
# Epoch 27/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9961
# Epoch 00027: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 70s 2s/step - loss: 0.0142 - accuracy: 0.9961 - val_loss: 3.9367 - val_accuracy: 0.5438 - lr: 0.0010
# Epoch 28/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9944
# Epoch 00028: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 70s 2s/step - loss: 0.0166 - accuracy: 0.9944 - val_loss: 3.2130 - val_accuracy: 0.5393 - lr: 0.0010
# Epoch 29/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9972
# Epoch 00029: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 1.1933 - val_accuracy: 0.7910 - lr: 0.0010
# Epoch 30/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9989
# Epoch 00030: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.4683 - val_accuracy: 0.8629 - lr: 0.0010
# Epoch 31/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9989
# Epoch 00031: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 70s 2s/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 1.1847 - val_accuracy: 0.7348 - lr: 0.0010
# Epoch 32/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9989
# Epoch 00032: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 1.9848 - val_accuracy: 0.6382 - lr: 0.0010
# Epoch 33/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9961
# Epoch 00033: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0083 - accuracy: 0.9961 - val_loss: 0.5965 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 34/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9994
# Epoch 00034: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 1.2904 - val_accuracy: 0.7596 - lr: 0.0010
# Epoch 35/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9994
# Epoch 00035: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.5478 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 36/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00036: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5953 - val_accuracy: 0.8629 - lr: 0.0010
# Epoch 37/100
# 28/28 [==============================] - ETA: 0s - loss: 5.6760e-04 - accuracy: 1.0000
# Epoch 00037: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 70s 2s/step - loss: 5.6760e-04 - accuracy: 1.0000 - val_loss: 0.6870 - val_accuracy: 0.8607 - lr: 0.0010
# Epoch 38/100
# 28/28 [==============================] - ETA: 0s - loss: 5.2133e-04 - accuracy: 1.0000
# Epoch 00038: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 70s 2s/step - loss: 5.2133e-04 - accuracy: 1.0000 - val_loss: 0.5239 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 39/100
# 28/28 [==============================] - ETA: 0s - loss: 2.2371e-04 - accuracy: 1.0000
# Epoch 00039: val_accuracy did not improve from 0.87416
# 28/28 [==============================] - 69s 2s/step - loss: 2.2371e-04 - accuracy: 1.0000 - val_loss: 0.5418 - val_accuracy: 0.8674 - lr: 0.0010
# Epoch 40/100
# 28/28 [==============================] - ETA: 0s - loss: 5.9063e-04 - accuracy: 1.0000
# Epoch 00040: val_accuracy did not improve from 0.87416
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 28/28 [==============================] - 70s 2s/step - loss: 5.9063e-04 - accuracy: 1.0000 - val_loss: 0.5229 - val_accuracy: 0.8719 - lr: 0.0010
# Epoch 41/100
# 28/28 [==============================] - ETA: 0s - loss: 2.4208e-04 - accuracy: 1.0000
# Epoch 00041: val_accuracy improved from 0.87416 to 0.87865, saving model to BiLSTM_V11_1.h5
# 28/28 [==============================] - 71s 3s/step - loss: 2.4208e-04 - accuracy: 1.0000 - val_loss: 0.5523 - val_accuracy: 0.8787 - lr: 5.0000e-04
# Epoch 42/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9312e-04 - accuracy: 1.0000
# Epoch 00042: val_accuracy improved from 0.87865 to 0.88090, saving model to BiLSTM_V11_1.h5
# 28/28 [==============================] - 70s 2s/step - loss: 1.9312e-04 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8809 - lr: 5.0000e-04
# Epoch 43/100
# 28/28 [==============================] - ETA: 0s - loss: 3.3119e-04 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.88090
# 28/28 [==============================] - 70s 3s/step - loss: 3.3119e-04 - accuracy: 1.0000 - val_loss: 0.5077 - val_accuracy: 0.8764 - lr: 5.0000e-04
# Epoch 44/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0821e-04 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.88090
# 28/28 [==============================] - 69s 2s/step - loss: 2.0821e-04 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.8697 - lr: 5.0000e-04
# Epoch 45/100
# 28/28 [==============================] - ETA: 0s - loss: 3.2478e-04 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.88090
# 28/28 [==============================] - 70s 2s/step - loss: 3.2478e-04 - accuracy: 1.0000 - val_loss: 0.4981 - val_accuracy: 0.8764 - lr: 5.0000e-04
# Epoch 46/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7970e-04 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.88090
# 28/28 [==============================] - 70s 2s/step - loss: 1.7970e-04 - accuracy: 1.0000 - val_loss: 0.5339 - val_accuracy: 0.8809 - lr: 5.0000e-04
# Epoch 47/100
# 28/28 [==============================] - ETA: 0s - loss: 2.5447e-04 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.88090
# 28/28 [==============================] - 69s 2s/step - loss: 2.5447e-04 - accuracy: 1.0000 - val_loss: 0.5491 - val_accuracy: 0.8719 - lr: 5.0000e-04
# Epoch 48/100
# 28/28 [==============================] - ETA: 0s - loss: 2.2165e-04 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.88090
# 28/28 [==============================] - 70s 2s/step - loss: 2.2165e-04 - accuracy: 1.0000 - val_loss: 0.5980 - val_accuracy: 0.8607 - lr: 5.0000e-04
# Epoch 49/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7486e-04 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.88090
# 28/28 [==============================] - 70s 2s/step - loss: 1.7486e-04 - accuracy: 1.0000 - val_loss: 0.6627 - val_accuracy: 0.8494 - lr: 5.0000e-04
# Epoch 50/100
# 28/28 [==============================] - ETA: 0s - loss: 4.2354e-04 - accuracy: 1.0000
# Epoch 00050: val_accuracy improved from 0.88090 to 0.88315, saving model to BiLSTM_V11_1.h5
# 28/28 [==============================] - 69s 2s/step - loss: 4.2354e-04 - accuracy: 1.0000 - val_loss: 0.5353 - val_accuracy: 0.8831 - lr: 5.0000e-04
# Epoch 51/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3888e-04 - accuracy: 1.0000
# Epoch 00051: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 70s 2s/step - loss: 1.3888e-04 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.8809 - lr: 5.0000e-04
# Epoch 52/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5053e-04 - accuracy: 1.0000
# Epoch 00052: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 2377s 85s/step - loss: 1.5053e-04 - accuracy: 1.0000 - val_loss: 0.5394 - val_accuracy: 0.8764 - lr: 5.0000e-04
# Epoch 53/100
# 28/28 [==============================] - ETA: 0s - loss: 1.6069e-04 - accuracy: 1.0000
# Epoch 00053: val_accuracy did not improve from 0.88315
# 28/28 [==============================] - 14332s 512s/step - loss: 1.6069e-04 - accuracy: 1.0000 - val_loss: 0.6224 - val_accuracy: 0.8562 - lr: 5.0000e-04
# Epoch 54/100
# 28/28 [==============================] - ETA: 0s - loss: 2.3107e-04 - accuracy: 1.0000
# Epoch 00054: val_accuracy improved from 0.88315 to 0.88764, saving model to BiLSTM_V11_1.h5
# 28/28 [==============================] - 14401s 514s/step - loss: 2.3107e-04 - accuracy: 1.0000 - val_loss: 0.5337 - val_accuracy: 0.8876 - lr: 5.0000e-04
# Epoch 55/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3397e-04 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 5740s 205s/step - loss: 1.3397e-04 - accuracy: 1.0000 - val_loss: 0.5055 - val_accuracy: 0.8719 - lr: 5.0000e-04
# Epoch 56/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8740e-04 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 146s 5s/step - loss: 1.8740e-04 - accuracy: 1.0000 - val_loss: 0.5072 - val_accuracy: 0.8742 - lr: 5.0000e-04
# Epoch 57/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3866e-04 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 147s 5s/step - loss: 1.3866e-04 - accuracy: 1.0000 - val_loss: 0.5284 - val_accuracy: 0.8854 - lr: 5.0000e-04
# Epoch 58/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0139e-04 - accuracy: 1.0000
# Epoch 00058: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 146s 5s/step - loss: 1.0139e-04 - accuracy: 1.0000 - val_loss: 0.5743 - val_accuracy: 0.8674 - lr: 5.0000e-04
# Epoch 59/100
# 28/28 [==============================] - ETA: 0s - loss: 2.5594e-04 - accuracy: 1.0000
# Epoch 00059: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 149s 5s/step - loss: 2.5594e-04 - accuracy: 1.0000 - val_loss: 0.7810 - val_accuracy: 0.8135 - lr: 5.0000e-04
# Epoch 60/100
# 28/28 [==============================] - ETA: 0s - loss: 1.8722e-04 - accuracy: 1.0000
# Epoch 00060: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 146s 5s/step - loss: 1.8722e-04 - accuracy: 1.0000 - val_loss: 0.8012 - val_accuracy: 0.8112 - lr: 5.0000e-04
# Epoch 61/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0996e-04 - accuracy: 1.0000
# Epoch 00061: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 161s 6s/step - loss: 2.0996e-04 - accuracy: 1.0000 - val_loss: 0.5690 - val_accuracy: 0.8674 - lr: 5.0000e-04
# Epoch 62/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9983
# Epoch 00062: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 158s 6s/step - loss: 0.0035 - accuracy: 0.9983 - val_loss: 0.5816 - val_accuracy: 0.8674 - lr: 5.0000e-04
# Epoch 63/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994
# Epoch 00063: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 156s 6s/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 0.5847 - val_accuracy: 0.8539 - lr: 5.0000e-04
# Epoch 64/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 00064: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 154s 5s/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 1.1693 - val_accuracy: 0.7551 - lr: 5.0000e-04
# Epoch 65/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 00065: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 148s 5s/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.7305 - val_accuracy: 0.8449 - lr: 5.0000e-04
# Epoch 66/100
# 28/28 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 00066: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 173s 6s/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.6764 - val_accuracy: 0.8562 - lr: 5.0000e-04
# Epoch 67/100
# 28/28 [==============================] - ETA: 0s - loss: 2.0756e-04 - accuracy: 1.0000
# Epoch 00067: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 175s 6s/step - loss: 2.0756e-04 - accuracy: 1.0000 - val_loss: 0.7246 - val_accuracy: 0.8607 - lr: 5.0000e-04
# Epoch 68/100
# 28/28 [==============================] - ETA: 0s - loss: 2.2204e-04 - accuracy: 1.0000
# Epoch 00068: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 175s 6s/step - loss: 2.2204e-04 - accuracy: 1.0000 - val_loss: 0.5757 - val_accuracy: 0.8719 - lr: 5.0000e-04
# Epoch 69/100
# 28/28 [==============================] - ETA: 0s - loss: 1.4928e-04 - accuracy: 1.0000
# Epoch 00069: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 177s 6s/step - loss: 1.4928e-04 - accuracy: 1.0000 - val_loss: 0.5609 - val_accuracy: 0.8809 - lr: 5.0000e-04
# Epoch 70/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9937e-04 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 176s 6s/step - loss: 1.9937e-04 - accuracy: 1.0000 - val_loss: 0.5505 - val_accuracy: 0.8787 - lr: 5.0000e-04
# Epoch 71/100
# 28/28 [==============================] - ETA: 0s - loss: 4.5423e-04 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 177s 6s/step - loss: 4.5423e-04 - accuracy: 1.0000 - val_loss: 0.9180 - val_accuracy: 0.8315 - lr: 5.0000e-04
# Epoch 72/100
# 28/28 [==============================] - ETA: 0s - loss: 3.2421e-04 - accuracy: 1.0000
# Epoch 00072: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 177s 6s/step - loss: 3.2421e-04 - accuracy: 1.0000 - val_loss: 0.5254 - val_accuracy: 0.8831 - lr: 5.0000e-04
# Epoch 73/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3479e-04 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 179s 6s/step - loss: 1.3479e-04 - accuracy: 1.0000 - val_loss: 0.5730 - val_accuracy: 0.8674 - lr: 5.0000e-04
# Epoch 74/100
# 28/28 [==============================] - ETA: 0s - loss: 8.9576e-05 - accuracy: 1.0000
# Epoch 00074: val_accuracy did not improve from 0.88764
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 28/28 [==============================] - 179s 6s/step - loss: 8.9576e-05 - accuracy: 1.0000 - val_loss: 0.5807 - val_accuracy: 0.8697 - lr: 5.0000e-04
# Epoch 75/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1512e-04 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 181s 6s/step - loss: 2.1512e-04 - accuracy: 1.0000 - val_loss: 0.6302 - val_accuracy: 0.8674 - lr: 2.5000e-04
# Epoch 76/100
# 28/28 [==============================] - ETA: 0s - loss: 9.7500e-05 - accuracy: 1.0000
# Epoch 00076: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 3369s 120s/step - loss: 9.7500e-05 - accuracy: 1.0000 - val_loss: 0.6109 - val_accuracy: 0.8652 - lr: 2.5000e-04
# Epoch 77/100
# 28/28 [==============================] - ETA: 0s - loss: 8.5406e-05 - accuracy: 1.0000
# Epoch 00077: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 8.5406e-05 - accuracy: 1.0000 - val_loss: 0.5758 - val_accuracy: 0.8697 - lr: 2.5000e-04
# Epoch 78/100
# 28/28 [==============================] - ETA: 0s - loss: 1.0716e-04 - accuracy: 1.0000
# Epoch 00078: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 1.0716e-04 - accuracy: 1.0000 - val_loss: 0.5776 - val_accuracy: 0.8697 - lr: 2.5000e-04
# Epoch 79/100
# 28/28 [==============================] - ETA: 0s - loss: 1.4724e-04 - accuracy: 1.0000
# Epoch 00079: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 70s 2s/step - loss: 1.4724e-04 - accuracy: 1.0000 - val_loss: 0.6114 - val_accuracy: 0.8674 - lr: 2.5000e-04
# Epoch 80/100
# 28/28 [==============================] - ETA: 0s - loss: 4.7379e-04 - accuracy: 1.0000
# Epoch 00080: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 67s 2s/step - loss: 4.7379e-04 - accuracy: 1.0000 - val_loss: 0.5202 - val_accuracy: 0.8831 - lr: 2.5000e-04
# Epoch 81/100
# 28/28 [==============================] - ETA: 0s - loss: 5.1573e-05 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 5.1573e-05 - accuracy: 1.0000 - val_loss: 0.6545 - val_accuracy: 0.8674 - lr: 2.5000e-04
# Epoch 82/100
# 28/28 [==============================] - ETA: 0s - loss: 1.3504e-04 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 1.3504e-04 - accuracy: 1.0000 - val_loss: 0.5006 - val_accuracy: 0.8876 - lr: 2.5000e-04
# Epoch 83/100
# 28/28 [==============================] - ETA: 0s - loss: 1.2736e-04 - accuracy: 1.0000
# Epoch 00083: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 69s 2s/step - loss: 1.2736e-04 - accuracy: 1.0000 - val_loss: 0.5449 - val_accuracy: 0.8742 - lr: 2.5000e-04
# Epoch 84/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1279e-04 - accuracy: 1.0000
# Epoch 00084: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 1.1279e-04 - accuracy: 1.0000 - val_loss: 0.6177 - val_accuracy: 0.8607 - lr: 2.5000e-04
# Epoch 85/100
# 28/28 [==============================] - ETA: 0s - loss: 1.1979e-04 - accuracy: 1.0000
# Epoch 00085: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 1.1979e-04 - accuracy: 1.0000 - val_loss: 0.5966 - val_accuracy: 0.8674 - lr: 2.5000e-04
# Epoch 86/100
# 28/28 [==============================] - ETA: 0s - loss: 4.9260e-05 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 4.9260e-05 - accuracy: 1.0000 - val_loss: 0.5740 - val_accuracy: 0.8674 - lr: 2.5000e-04
# Epoch 87/100
# 28/28 [==============================] - ETA: 0s - loss: 9.4307e-05 - accuracy: 1.0000
# Epoch 00087: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 67s 2s/step - loss: 9.4307e-05 - accuracy: 1.0000 - val_loss: 0.5699 - val_accuracy: 0.8674 - lr: 2.5000e-04
# Epoch 88/100
# 28/28 [==============================] - ETA: 0s - loss: 3.5800e-04 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 67s 2s/step - loss: 3.5800e-04 - accuracy: 1.0000 - val_loss: 0.5148 - val_accuracy: 0.8854 - lr: 2.5000e-04
# Epoch 89/100
# 28/28 [==============================] - ETA: 0s - loss: 8.3711e-05 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 8.3711e-05 - accuracy: 1.0000 - val_loss: 0.4993 - val_accuracy: 0.8876 - lr: 2.5000e-04
# Epoch 90/100
# 28/28 [==============================] - ETA: 0s - loss: 3.2051e-05 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 3.2051e-05 - accuracy: 1.0000 - val_loss: 0.5097 - val_accuracy: 0.8854 - lr: 2.5000e-04
# Epoch 91/100
# 28/28 [==============================] - ETA: 0s - loss: 1.9564e-04 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 69s 2s/step - loss: 1.9564e-04 - accuracy: 1.0000 - val_loss: 0.6525 - val_accuracy: 0.8517 - lr: 2.5000e-04
# Epoch 92/100
# 28/28 [==============================] - ETA: 0s - loss: 2.1563e-04 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 2.1563e-04 - accuracy: 1.0000 - val_loss: 1.0517 - val_accuracy: 0.7753 - lr: 2.5000e-04
# Epoch 93/100
# 28/28 [==============================] - ETA: 0s - loss: 9.5484e-05 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 9.5484e-05 - accuracy: 1.0000 - val_loss: 0.8665 - val_accuracy: 0.8157 - lr: 2.5000e-04
# Epoch 94/100
# 28/28 [==============================] - ETA: 0s - loss: 7.3933e-05 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.88764
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 28/28 [==============================] - 68s 2s/step - loss: 7.3933e-05 - accuracy: 1.0000 - val_loss: 0.6202 - val_accuracy: 0.8539 - lr: 2.5000e-04
# Epoch 95/100
# 28/28 [==============================] - ETA: 0s - loss: 5.9039e-05 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 69s 2s/step - loss: 5.9039e-05 - accuracy: 1.0000 - val_loss: 0.5890 - val_accuracy: 0.8697 - lr: 1.2500e-04
# Epoch 96/100
# 28/28 [==============================] - ETA: 0s - loss: 4.6315e-05 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 4.6315e-05 - accuracy: 1.0000 - val_loss: 0.5759 - val_accuracy: 0.8697 - lr: 1.2500e-04
# Epoch 97/100
# 28/28 [==============================] - ETA: 0s - loss: 1.5178e-04 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 69s 2s/step - loss: 1.5178e-04 - accuracy: 1.0000 - val_loss: 0.6330 - val_accuracy: 0.8517 - lr: 1.2500e-04
# Epoch 98/100
# 28/28 [==============================] - ETA: 0s - loss: 6.3512e-05 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 6.3512e-05 - accuracy: 1.0000 - val_loss: 0.6179 - val_accuracy: 0.8584 - lr: 1.2500e-04
# Epoch 99/100
# 28/28 [==============================] - ETA: 0s - loss: 1.7350e-04 - accuracy: 1.0000
# Epoch 00099: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 1.7350e-04 - accuracy: 1.0000 - val_loss: 0.6540 - val_accuracy: 0.8472 - lr: 1.2500e-04
# Epoch 100/100
# 28/28 [==============================] - ETA: 0s - loss: 4.4966e-05 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.88764
# 28/28 [==============================] - 68s 2s/step - loss: 4.4966e-05 - accuracy: 1.0000 - val_loss: 0.6056 - val_accuracy: 0.8629 - lr: 1.2500e-04

# %%
# 可视化训练过程中，训练集与验证集的损失和精度
plt.figure(figsize=(16,8))
plt.subplot(121)
plt.plot(history.history['loss'],label = 'train_loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()

plt.subplot(122)
plt.plot(history.history['accuracy'],label = 'train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: SimHei

# %%
# 使用模型得到预测结果
model = load_model('BiLSTM_V11_1.h5')
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
print('在80%训练集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1)), recall_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary'), f1_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary')))
print('在20%测试集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1)), recall_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary'), f1_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary')))
# Out:
# 在80%训练集上, accuracy: 1.0% 召回率:  1.0, f1:  1.0
# 在20%测试集上, accuracy: 0.8876% 召回率: 0.9246861924686193, f1: 0.8983739837398375

# %%
# 绘制混淆矩阵
plt.figure(figsize=(16,8))
plt.subplot(121)
matrix = confusion_matrix(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Train confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.subplot(122)
matrix = confusion_matrix(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Test confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.show()
