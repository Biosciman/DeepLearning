# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, ReLU, Bidirectional,BatchNormalization, Conv1D, MaxPool1D
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] =False
plt.rcParams.update({"font.size":20})
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, f1_score, recall_score

# %%
negative = pd.read_csv('data/Negative.txt', header = None, index_col=None) 
negative = negative.drop_duplicates()
negative['label'] = 0
positive = pd.read_csv('data/Positive.txt', header = None, index_col=None) 
positive = positive.drop_duplicates()
positive['label'] = 1
# negative[negative.isnull().values==True] # 判断是否存在缺失值

# %%
data = pd.concat([negative, positive], axis=0).reset_index().iloc[:, 1:]
data = data.dropna()

# %%
# 数据归一化处理
x_data = data.iloc[:, :-1]
y_data = data.loc[:, 'label']
mm = MinMaxScaler([-1, 1])
x_data_mm = mm.fit_transform(x_data)
# 数据降维
# pca = PCA(n_components=10) 
# x_data_mm_pca = pca.fit_transform(x_data_mm)
# 类别均衡化
model_smote = SMOTE()  
x_resampled, y_resampled = model_smote.fit_resample(x_data_mm,y_data)

# %%
# 划分训练数据为80%训练集和20%的验证集
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=7, shuffle=True)

# %%
# 重置数据维度
x_train = x_train.reshape(-1,1,x_train.shape[-1])
x_test = x_test.reshape(-1,1,x_test.shape[-1])
print(x_train.shape)
# Out:
# (1777, 1, 2000)

# %%
# 对类别数据进行onehot编码
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# %%
# 构建网络
model = Sequential() 

model.add(Conv1D(128,16, activation='relu', padding='same'))
model.add(Conv1D(128,8, activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPool1D(pool_size=5, padding='same'))


model.add(Bidirectional(LSTM(units=64, return_sequences=True, activation='relu', input_dim=x_train.shape[-1], input_length=x_train.shape[1])))
model.add(BatchNormalization())
model.add(Bidirectional(LSTM(units=64)))
model.add(BatchNormalization())
model.add(Dense(2, activation = 'softmax'))

model.build(input_shape=x_train.shape)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              multiple                  4096128
# _________________________________________________________________
# conv1d_1 (Conv1D)            multiple                  131200
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  512
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) multiple                  0
# _________________________________________________________________
# bidirectional (Bidirectional multiple                  98816
# _________________________________________________________________
# batch_normalization_1 (Batch multiple                  512
# _________________________________________________________________
# bidirectional_1 (Bidirection multiple                  98816
# _________________________________________________________________
# batch_normalization_2 (Batch multiple                  512
# _________________________________________________________________
# dense (Dense)                multiple                  258
# =================================================================
# Total params: 4,426,754
# Trainable params: 4,425,986
# Non-trainable params: 768
# _________________________________________________________________

# %%
# 训练网络
epochs = 200 # 训练周期
batch_size = 64 # 批次大小 
# 监视网络的训练，并将在验证集上取得最优结果的网络权重保留下来
checkpoint = ModelCheckpoint("BiLSTM_V8_10.h5", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max') 
# 监视网络的训练，并对学习率进行衰减处理
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=20, verbose=1)
callbacks_list = [checkpoint, reduce_lr] # 监视列表 
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy']) # 编译网络
# 开始训练，直接使用30%的验证集，在训练过程中测试网络
history = model.fit(x_train, y_train, callbacks=callbacks_list, epochs=epochs, batch_size=batch_size, verbose=1,validation_data=(x_test, y_test))
# Out:
# Epoch 1/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0464 - accuracy: 0.9876
# Epoch 00001: val_accuracy improved from -inf to 0.51685, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 4s 146ms/step - loss: 0.0464 - accuracy: 0.9876 - val_loss: 4.1279 - val_accuracy: 0.5169 - lr: 0.0010
# Epoch 2/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0754 - accuracy: 0.9814
# Epoch 00002: val_accuracy improved from 0.51685 to 0.53708, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0754 - accuracy: 0.9814 - val_loss: 10.2427 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 3/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9859
# Epoch 00003: val_accuracy improved from 0.53708 to 0.53933, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 3s 118ms/step - loss: 0.0356 - accuracy: 0.9859 - val_loss: 7.2152 - val_accuracy: 0.5393 - lr: 0.0010
# Epoch 4/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9966
# Epoch 00004: val_accuracy improved from 0.53933 to 0.73034, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 3s 117ms/step - loss: 0.0131 - accuracy: 0.9966 - val_loss: 1.6013 - val_accuracy: 0.7303 - lr: 0.0010
# Epoch 5/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9983
# Epoch 00005: val_accuracy did not improve from 0.73034
# 28/28 [==============================] - 3s 117ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 3.5002 - val_accuracy: 0.5753 - lr: 0.0010
# Epoch 6/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9932
# Epoch 00006: val_accuracy did not improve from 0.73034
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0299 - accuracy: 0.9932 - val_loss: 9.2224 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 7/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9899
# Epoch 00007: val_accuracy did not improve from 0.73034
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0316 - accuracy: 0.9899 - val_loss: 6.7563 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 8/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9944
# Epoch 00008: val_accuracy did not improve from 0.73034
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 6.2867 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 9/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9876
# Epoch 00009: val_accuracy did not improve from 0.73034
# 28/28 [==============================] - 3s 119ms/step - loss: 0.0341 - accuracy: 0.9876 - val_loss: 1.9462 - val_accuracy: 0.5483 - lr: 0.0010
# Epoch 10/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9826
# Epoch 00010: val_accuracy did not improve from 0.73034
# 28/28 [==============================] - 3s 116ms/step - loss: 0.0480 - accuracy: 0.9826 - val_loss: 3.6781 - val_accuracy: 0.4112 - lr: 0.0010
# Epoch 11/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9848
# Epoch 00011: val_accuracy did not improve from 0.73034
# 28/28 [==============================] - 3s 114ms/step - loss: 0.0447 - accuracy: 0.9848 - val_loss: 2.3813 - val_accuracy: 0.3798 - lr: 0.0010
# Epoch 12/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0265 - accuracy: 0.9887
# Epoch 00012: val_accuracy did not improve from 0.73034
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0265 - accuracy: 0.9887 - val_loss: 1.5651 - val_accuracy: 0.6045 - lr: 0.0010
# Epoch 13/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9932
# Epoch 00013: val_accuracy improved from 0.73034 to 0.78652, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 3s 118ms/step - loss: 0.0149 - accuracy: 0.9932 - val_loss: 0.9537 - val_accuracy: 0.7865 - lr: 0.0010
# Epoch 14/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9972
# Epoch 00014: val_accuracy did not improve from 0.78652
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0053 - accuracy: 0.9972 - val_loss: 3.8811 - val_accuracy: 0.6584 - lr: 0.0010
# Epoch 15/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9989
# Epoch 00015: val_accuracy improved from 0.78652 to 0.83146, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 3s 118ms/step - loss: 0.0087 - accuracy: 0.9989 - val_loss: 1.0203 - val_accuracy: 0.8315 - lr: 0.0010
# Epoch 16/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9983
# Epoch 00016: val_accuracy improved from 0.83146 to 0.85393, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 3s 117ms/step - loss: 0.0044 - accuracy: 0.9983 - val_loss: 0.8891 - val_accuracy: 0.8539 - lr: 0.0010
# Epoch 17/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9955
# Epoch 00017: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 117ms/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 3.4865 - val_accuracy: 0.5596 - lr: 0.0010
# Epoch 18/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0161 - accuracy: 0.9944
# Epoch 00018: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 2.4087 - val_accuracy: 0.6652 - lr: 0.0010
# Epoch 19/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9887
# Epoch 00019: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0407 - accuracy: 0.9887 - val_loss: 2.9176 - val_accuracy: 0.5101 - lr: 0.0010
# Epoch 20/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9837
# Epoch 00020: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0517 - accuracy: 0.9837 - val_loss: 5.2575 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 21/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9893
# Epoch 00021: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0367 - accuracy: 0.9893 - val_loss: 1.4062 - val_accuracy: 0.5978 - lr: 0.0010
# Epoch 22/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0169 - accuracy: 0.9938
# Epoch 00022: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0169 - accuracy: 0.9938 - val_loss: 7.3309 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 23/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9961
# Epoch 00023: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 116ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 4.8586 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 24/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9994
# Epoch 00024: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 4.1785 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 25/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0134 - accuracy: 0.9938
# Epoch 00025: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 118ms/step - loss: 0.0134 - accuracy: 0.9938 - val_loss: 2.8622 - val_accuracy: 0.5528 - lr: 0.0010
# Epoch 26/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9927
# Epoch 00026: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 118ms/step - loss: 0.0268 - accuracy: 0.9927 - val_loss: 4.1738 - val_accuracy: 0.5146 - lr: 0.0010
# Epoch 27/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9955
# Epoch 00027: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 116ms/step - loss: 0.0115 - accuracy: 0.9955 - val_loss: 9.0926 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 28/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9966
# Epoch 00028: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 3.2245 - val_accuracy: 0.5820 - lr: 0.0010
# Epoch 29/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9955
# Epoch 00029: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 114ms/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 2.9170 - val_accuracy: 0.5865 - lr: 0.0010
# Epoch 30/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9989
# Epoch 00030: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0058 - accuracy: 0.9989 - val_loss: 1.5845 - val_accuracy: 0.7034 - lr: 0.0010
# Epoch 31/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9983
# Epoch 00031: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 1.5527 - val_accuracy: 0.7124 - lr: 0.0010
# Epoch 32/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 0.9882
# Epoch 00032: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0379 - accuracy: 0.9882 - val_loss: 8.8602 - val_accuracy: 0.5483 - lr: 0.0010
# Epoch 33/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9949
# Epoch 00033: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 2.9982 - val_accuracy: 0.6607 - lr: 0.0010
# Epoch 34/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9904
# Epoch 00034: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 112ms/step - loss: 0.0274 - accuracy: 0.9904 - val_loss: 2.7758 - val_accuracy: 0.7056 - lr: 0.0010
# Epoch 35/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9921
# Epoch 00035: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0189 - accuracy: 0.9921 - val_loss: 1.2467 - val_accuracy: 0.7640 - lr: 0.0010
# Epoch 36/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 0.9983
# Epoch 00036: val_accuracy did not improve from 0.85393
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 28/28 [==============================] - 3s 114ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 4.2104 - val_accuracy: 0.6629 - lr: 0.0010
# Epoch 37/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9977
# Epoch 00037: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0044 - accuracy: 0.9977 - val_loss: 3.5500 - val_accuracy: 0.6607 - lr: 5.0000e-04
# Epoch 38/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9989
# Epoch 00038: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 2.6773 - val_accuracy: 0.6764 - lr: 5.0000e-04
# Epoch 39/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9989
# Epoch 00039: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0024 - accuracy: 0.9989 - val_loss: 1.7237 - val_accuracy: 0.7079 - lr: 5.0000e-04
# Epoch 40/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9989
# Epoch 00040: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 1.4120 - val_accuracy: 0.7528 - lr: 5.0000e-04
# Epoch 41/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 00041: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 115ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 1.0154 - val_accuracy: 0.8404 - lr: 5.0000e-04
# Epoch 42/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9966
# Epoch 00042: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 113ms/step - loss: 0.0090 - accuracy: 0.9966 - val_loss: 4.3548 - val_accuracy: 0.5258 - lr: 5.0000e-04
# Epoch 43/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9983
# Epoch 00043: val_accuracy did not improve from 0.85393
# 28/28 [==============================] - 3s 117ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 2.1240 - val_accuracy: 0.6404 - lr: 5.0000e-04
# Epoch 44/200
# 28/28 [==============================] - ETA: 0s - loss: 7.6027e-04 - accuracy: 1.0000
# Epoch 00044: val_accuracy improved from 0.85393 to 0.86517, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 3s 125ms/step - loss: 7.6027e-04 - accuracy: 1.0000 - val_loss: 0.8819 - val_accuracy: 0.8652 - lr: 5.0000e-04
# Epoch 45/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9983
# Epoch 00045: val_accuracy did not improve from 0.86517
# 28/28 [==============================] - 4s 132ms/step - loss: 0.0032 - accuracy: 0.9983 - val_loss: 0.8035 - val_accuracy: 0.8337 - lr: 5.0000e-04
# Epoch 46/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9994
# Epoch 00046: val_accuracy did not improve from 0.86517
# 28/28 [==============================] - 3s 121ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 11.0283 - val_accuracy: 0.5551 - lr: 5.0000e-04
# Epoch 47/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00047: val_accuracy did not improve from 0.86517
# 28/28 [==============================] - 4s 125ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 12.3868 - val_accuracy: 0.5438 - lr: 5.0000e-04
# Epoch 48/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00048: val_accuracy did not improve from 0.86517
# 28/28 [==============================] - 3s 120ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 7.6568 - val_accuracy: 0.6360 - lr: 5.0000e-04
# Epoch 49/200
# 28/28 [==============================] - ETA: 0s - loss: 3.4742e-04 - accuracy: 1.0000
# Epoch 00049: val_accuracy did not improve from 0.86517
# 28/28 [==============================] - 3s 119ms/step - loss: 3.4742e-04 - accuracy: 1.0000 - val_loss: 4.4381 - val_accuracy: 0.7101 - lr: 5.0000e-04
# Epoch 50/200
# 28/28 [==============================] - ETA: 0s - loss: 4.9973e-04 - accuracy: 1.0000
# Epoch 00050: val_accuracy did not improve from 0.86517
# 28/28 [==============================] - 3s 121ms/step - loss: 4.9973e-04 - accuracy: 1.0000 - val_loss: 2.9552 - val_accuracy: 0.7820 - lr: 5.0000e-04
# Epoch 51/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 0.9949
# Epoch 00051: val_accuracy did not improve from 0.86517
# 28/28 [==============================] - 3s 121ms/step - loss: 0.0172 - accuracy: 0.9949 - val_loss: 1.8107 - val_accuracy: 0.7506 - lr: 5.0000e-04
# Epoch 52/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9977
# Epoch 00052: val_accuracy did not improve from 0.86517
# 28/28 [==============================] - 4s 143ms/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 10.2027 - val_accuracy: 0.5416 - lr: 5.0000e-04
# Epoch 53/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9966
# Epoch 00053: val_accuracy did not improve from 0.86517
# 28/28 [==============================] - 5s 173ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.9167 - val_accuracy: 0.8607 - lr: 5.0000e-04
# Epoch 54/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9989
# Epoch 00054: val_accuracy improved from 0.86517 to 0.91236, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 5s 173ms/step - loss: 0.0025 - accuracy: 0.9989 - val_loss: 0.7360 - val_accuracy: 0.9124 - lr: 5.0000e-04
# Epoch 55/200
# 28/28 [==============================] - ETA: 0s - loss: 4.1523e-04 - accuracy: 1.0000
# Epoch 00055: val_accuracy did not improve from 0.91236
# 28/28 [==============================] - 5s 185ms/step - loss: 4.1523e-04 - accuracy: 1.0000 - val_loss: 0.8586 - val_accuracy: 0.8966 - lr: 5.0000e-04
# Epoch 56/200
# 28/28 [==============================] - ETA: 0s - loss: 2.7656e-04 - accuracy: 1.0000
# Epoch 00056: val_accuracy did not improve from 0.91236
# 28/28 [==============================] - 4s 158ms/step - loss: 2.7656e-04 - accuracy: 1.0000 - val_loss: 0.8336 - val_accuracy: 0.9011 - lr: 5.0000e-04
# Epoch 57/200
# 28/28 [==============================] - ETA: 0s - loss: 4.3414e-04 - accuracy: 1.0000
# Epoch 00057: val_accuracy did not improve from 0.91236
# 28/28 [==============================] - 4s 160ms/step - loss: 4.3414e-04 - accuracy: 1.0000 - val_loss: 0.7847 - val_accuracy: 0.9034 - lr: 5.0000e-04
# Epoch 58/200
# 28/28 [==============================] - ETA: 0s - loss: 2.3949e-04 - accuracy: 1.0000
# Epoch 00058: val_accuracy did not improve from 0.91236
# 28/28 [==============================] - 5s 164ms/step - loss: 2.3949e-04 - accuracy: 1.0000 - val_loss: 0.7482 - val_accuracy: 0.9124 - lr: 5.0000e-04
# Epoch 59/200
# 28/28 [==============================] - ETA: 0s - loss: 5.0547e-04 - accuracy: 1.0000
# Epoch 00059: val_accuracy improved from 0.91236 to 0.92135, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 5s 171ms/step - loss: 5.0547e-04 - accuracy: 1.0000 - val_loss: 0.7068 - val_accuracy: 0.9213 - lr: 5.0000e-04
# Epoch 60/200
# 28/28 [==============================] - ETA: 0s - loss: 2.1634e-04 - accuracy: 1.0000
# Epoch 00060: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 5s 166ms/step - loss: 2.1634e-04 - accuracy: 1.0000 - val_loss: 0.9194 - val_accuracy: 0.8472 - lr: 5.0000e-04
# Epoch 61/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9977
# Epoch 00061: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 5s 175ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 1.5318 - val_accuracy: 0.7506 - lr: 5.0000e-04
# Epoch 62/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9983
# Epoch 00062: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 5s 180ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.9756 - val_accuracy: 0.8045 - lr: 5.0000e-04
# Epoch 63/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 0.9994
# Epoch 00063: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 5s 171ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 1.5922 - val_accuracy: 0.7146 - lr: 5.0000e-04
# Epoch 64/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9983
# Epoch 00064: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 5s 162ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 3.4624 - val_accuracy: 0.6202 - lr: 5.0000e-04
# Epoch 65/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9977
# Epoch 00065: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 5s 180ms/step - loss: 0.0041 - accuracy: 0.9977 - val_loss: 0.6951 - val_accuracy: 0.8652 - lr: 5.0000e-04
# Epoch 66/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 00066: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 5s 188ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.6485 - val_accuracy: 0.8652 - lr: 5.0000e-04
# Epoch 67/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.9994
# Epoch 00067: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 209ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 1.6579 - val_accuracy: 0.7056 - lr: 5.0000e-04
# Epoch 68/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9977
# Epoch 00068: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 203ms/step - loss: 0.0045 - accuracy: 0.9977 - val_loss: 1.8563 - val_accuracy: 0.7146 - lr: 5.0000e-04
# Epoch 69/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00069: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 209ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.6088 - val_accuracy: 0.7461 - lr: 5.0000e-04
# Epoch 70/200
# 28/28 [==============================] - ETA: 0s - loss: 4.0882e-04 - accuracy: 1.0000
# Epoch 00070: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 212ms/step - loss: 4.0882e-04 - accuracy: 1.0000 - val_loss: 1.1732 - val_accuracy: 0.8067 - lr: 5.0000e-04
# Epoch 71/200
# 28/28 [==============================] - ETA: 0s - loss: 4.4625e-04 - accuracy: 1.0000
# Epoch 00071: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 206ms/step - loss: 4.4625e-04 - accuracy: 1.0000 - val_loss: 0.9102 - val_accuracy: 0.8742 - lr: 5.0000e-04
# Epoch 72/200
# 28/28 [==============================] - ETA: 0s - loss: 4.4301e-04 - accuracy: 1.0000
# Epoch 00072: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 207ms/step - loss: 4.4301e-04 - accuracy: 1.0000 - val_loss: 0.8483 - val_accuracy: 0.8921 - lr: 5.0000e-04
# Epoch 73/200
# 28/28 [==============================] - ETA: 0s - loss: 2.6032e-04 - accuracy: 1.0000
# Epoch 00073: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 206ms/step - loss: 2.6032e-04 - accuracy: 1.0000 - val_loss: 0.7215 - val_accuracy: 0.9056 - lr: 5.0000e-04
# Epoch 74/200
# 28/28 [==============================] - ETA: 0s - loss: 9.4321e-04 - accuracy: 0.9994
# Epoch 00074: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 213ms/step - loss: 9.4321e-04 - accuracy: 0.9994 - val_loss: 0.9875 - val_accuracy: 0.8090 - lr: 5.0000e-04
# Epoch 75/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00075: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 205ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.9192 - val_accuracy: 0.8270 - lr: 5.0000e-04
# Epoch 76/200
# 28/28 [==============================] - ETA: 0s - loss: 5.4631e-04 - accuracy: 1.0000
# Epoch 00076: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 225ms/step - loss: 5.4631e-04 - accuracy: 1.0000 - val_loss: 0.8061 - val_accuracy: 0.8719 - lr: 5.0000e-04
# Epoch 77/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9983
# Epoch 00077: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 7s 240ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.9269 - val_accuracy: 0.8607 - lr: 5.0000e-04
# Epoch 78/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9983
# Epoch 00078: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 214ms/step - loss: 0.0031 - accuracy: 0.9983 - val_loss: 2.1830 - val_accuracy: 0.6966 - lr: 5.0000e-04
# Epoch 79/200
# 28/28 [==============================] - ETA: 0s - loss: 6.0043e-04 - accuracy: 1.0000
# Epoch 00079: val_accuracy did not improve from 0.92135
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 28/28 [==============================] - 6s 213ms/step - loss: 6.0043e-04 - accuracy: 1.0000 - val_loss: 2.3339 - val_accuracy: 0.6764 - lr: 5.0000e-04
# Epoch 80/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994
# Epoch 00080: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 217ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.8493 - val_accuracy: 0.8225 - lr: 2.5000e-04
# Epoch 81/200
# 28/28 [==============================] - ETA: 0s - loss: 6.4881e-04 - accuracy: 1.0000
# Epoch 00081: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 216ms/step - loss: 6.4881e-04 - accuracy: 1.0000 - val_loss: 0.8021 - val_accuracy: 0.8225 - lr: 2.5000e-04
# Epoch 82/200
# 28/28 [==============================] - ETA: 0s - loss: 8.1906e-04 - accuracy: 1.0000
# Epoch 00082: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 210ms/step - loss: 8.1906e-04 - accuracy: 1.0000 - val_loss: 1.0310 - val_accuracy: 0.8112 - lr: 2.5000e-04
# Epoch 83/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9994
# Epoch 00083: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 214ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.7530 - val_accuracy: 0.8719 - lr: 2.5000e-04
# Epoch 84/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9994
# Epoch 00084: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 215ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.7434 - val_accuracy: 0.8831 - lr: 2.5000e-04
# Epoch 85/200
# 28/28 [==============================] - ETA: 0s - loss: 9.6393e-04 - accuracy: 0.9994
# Epoch 00085: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 211ms/step - loss: 9.6393e-04 - accuracy: 0.9994 - val_loss: 0.6917 - val_accuracy: 0.9079 - lr: 2.5000e-04
# Epoch 86/200
# 28/28 [==============================] - ETA: 0s - loss: 6.7745e-04 - accuracy: 1.0000
# Epoch 00086: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 212ms/step - loss: 6.7745e-04 - accuracy: 1.0000 - val_loss: 1.1851 - val_accuracy: 0.8787 - lr: 2.5000e-04
# Epoch 87/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9994
# Epoch 00087: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 207ms/step - loss: 0.0010 - accuracy: 0.9994 - val_loss: 1.4902 - val_accuracy: 0.8382 - lr: 2.5000e-04
# Epoch 88/200
# 28/28 [==============================] - ETA: 0s - loss: 3.6284e-04 - accuracy: 1.0000
# Epoch 00088: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 215ms/step - loss: 3.6284e-04 - accuracy: 1.0000 - val_loss: 1.0522 - val_accuracy: 0.8629 - lr: 2.5000e-04
# Epoch 89/200
# 28/28 [==============================] - ETA: 0s - loss: 3.2709e-04 - accuracy: 1.0000
# Epoch 00089: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 214ms/step - loss: 3.2709e-04 - accuracy: 1.0000 - val_loss: 0.8443 - val_accuracy: 0.8854 - lr: 2.5000e-04
# Epoch 90/200
# 28/28 [==============================] - ETA: 0s - loss: 5.1625e-04 - accuracy: 1.0000
# Epoch 00090: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 215ms/step - loss: 5.1625e-04 - accuracy: 1.0000 - val_loss: 0.6933 - val_accuracy: 0.9124 - lr: 2.5000e-04
# Epoch 91/200
# 28/28 [==============================] - ETA: 0s - loss: 3.5062e-04 - accuracy: 1.0000
# Epoch 00091: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 212ms/step - loss: 3.5062e-04 - accuracy: 1.0000 - val_loss: 0.7137 - val_accuracy: 0.9101 - lr: 2.5000e-04
# Epoch 92/200
# 28/28 [==============================] - ETA: 0s - loss: 1.7031e-04 - accuracy: 1.0000
# Epoch 00092: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 217ms/step - loss: 1.7031e-04 - accuracy: 1.0000 - val_loss: 0.7260 - val_accuracy: 0.9101 - lr: 2.5000e-04
# Epoch 93/200
# 28/28 [==============================] - ETA: 0s - loss: 2.2688e-04 - accuracy: 1.0000
# Epoch 00093: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 209ms/step - loss: 2.2688e-04 - accuracy: 1.0000 - val_loss: 0.7047 - val_accuracy: 0.9124 - lr: 2.5000e-04
# Epoch 94/200
# 28/28 [==============================] - ETA: 0s - loss: 1.7101e-04 - accuracy: 1.0000
# Epoch 00094: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 214ms/step - loss: 1.7101e-04 - accuracy: 1.0000 - val_loss: 0.7046 - val_accuracy: 0.9169 - lr: 2.5000e-04
# Epoch 95/200
# 28/28 [==============================] - ETA: 0s - loss: 2.0983e-04 - accuracy: 1.0000
# Epoch 00095: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 211ms/step - loss: 2.0983e-04 - accuracy: 1.0000 - val_loss: 0.7523 - val_accuracy: 0.9124 - lr: 2.5000e-04
# Epoch 96/200
# 28/28 [==============================] - ETA: 0s - loss: 2.0220e-04 - accuracy: 1.0000
# Epoch 00096: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 216ms/step - loss: 2.0220e-04 - accuracy: 1.0000 - val_loss: 0.6806 - val_accuracy: 0.9169 - lr: 2.5000e-04
# Epoch 97/200
# 28/28 [==============================] - ETA: 0s - loss: 1.5586e-04 - accuracy: 1.0000
# Epoch 00097: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 212ms/step - loss: 1.5586e-04 - accuracy: 1.0000 - val_loss: 0.6992 - val_accuracy: 0.9146 - lr: 2.5000e-04
# Epoch 98/200
# 28/28 [==============================] - ETA: 0s - loss: 2.2368e-04 - accuracy: 1.0000
# Epoch 00098: val_accuracy did not improve from 0.92135
# 28/28 [==============================] - 6s 213ms/step - loss: 2.2368e-04 - accuracy: 1.0000 - val_loss: 0.6567 - val_accuracy: 0.9191 - lr: 2.5000e-04
# Epoch 99/200
# 28/28 [==============================] - ETA: 0s - loss: 8.5179e-04 - accuracy: 0.9994
# Epoch 00099: val_accuracy improved from 0.92135 to 0.92360, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 6s 219ms/step - loss: 8.5179e-04 - accuracy: 0.9994 - val_loss: 0.6274 - val_accuracy: 0.9236 - lr: 2.5000e-04
# Epoch 100/200
# 28/28 [==============================] - ETA: 0s - loss: 1.7201e-04 - accuracy: 1.0000
# Epoch 00100: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 215ms/step - loss: 1.7201e-04 - accuracy: 1.0000 - val_loss: 1.1425 - val_accuracy: 0.7933 - lr: 2.5000e-04
# Epoch 101/200
# 28/28 [==============================] - ETA: 0s - loss: 8.0989e-04 - accuracy: 1.0000
# Epoch 00101: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 211ms/step - loss: 8.0989e-04 - accuracy: 1.0000 - val_loss: 0.6796 - val_accuracy: 0.8989 - lr: 2.5000e-04
# Epoch 102/200
# 28/28 [==============================] - ETA: 0s - loss: 2.6907e-04 - accuracy: 1.0000
# Epoch 00102: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 223ms/step - loss: 2.6907e-04 - accuracy: 1.0000 - val_loss: 0.8611 - val_accuracy: 0.8921 - lr: 2.5000e-04
# Epoch 103/200
# 28/28 [==============================] - ETA: 0s - loss: 3.1876e-04 - accuracy: 1.0000
# Epoch 00103: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 211ms/step - loss: 3.1876e-04 - accuracy: 1.0000 - val_loss: 0.8378 - val_accuracy: 0.9011 - lr: 2.5000e-04
# Epoch 104/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 00104: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 210ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 1.2099 - val_accuracy: 0.8135 - lr: 2.5000e-04
# Epoch 105/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9994
# Epoch 00105: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 218ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 1.0492 - val_accuracy: 0.8225 - lr: 2.5000e-04
# Epoch 106/200
# 28/28 [==============================] - ETA: 0s - loss: 2.5071e-04 - accuracy: 1.0000
# Epoch 00106: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 212ms/step - loss: 2.5071e-04 - accuracy: 1.0000 - val_loss: 0.7162 - val_accuracy: 0.8831 - lr: 2.5000e-04
# Epoch 107/200
# 28/28 [==============================] - ETA: 0s - loss: 3.3211e-04 - accuracy: 1.0000
# Epoch 00107: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 214ms/step - loss: 3.3211e-04 - accuracy: 1.0000 - val_loss: 0.6973 - val_accuracy: 0.9146 - lr: 2.5000e-04
# Epoch 108/200
# 28/28 [==============================] - ETA: 0s - loss: 9.9415e-05 - accuracy: 1.0000
# Epoch 00108: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 212ms/step - loss: 9.9415e-05 - accuracy: 1.0000 - val_loss: 0.6985 - val_accuracy: 0.9146 - lr: 2.5000e-04
# Epoch 109/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9994
# Epoch 00109: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 212ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 1.4994 - val_accuracy: 0.7618 - lr: 2.5000e-04
# Epoch 110/200
# 28/28 [==============================] - ETA: 0s - loss: 6.9671e-04 - accuracy: 1.0000
# Epoch 00110: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 212ms/step - loss: 6.9671e-04 - accuracy: 1.0000 - val_loss: 0.7519 - val_accuracy: 0.9101 - lr: 2.5000e-04
# Epoch 111/200
# 28/28 [==============================] - ETA: 0s - loss: 2.5887e-04 - accuracy: 1.0000
# Epoch 00111: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 207ms/step - loss: 2.5887e-04 - accuracy: 1.0000 - val_loss: 0.9616 - val_accuracy: 0.9056 - lr: 2.5000e-04
# Epoch 112/200
# 28/28 [==============================] - ETA: 0s - loss: 3.3103e-04 - accuracy: 1.0000
# Epoch 00112: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 214ms/step - loss: 3.3103e-04 - accuracy: 1.0000 - val_loss: 0.7969 - val_accuracy: 0.9236 - lr: 2.5000e-04
# Epoch 113/200
# 28/28 [==============================] - ETA: 0s - loss: 2.7951e-04 - accuracy: 1.0000
# Epoch 00113: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 209ms/step - loss: 2.7951e-04 - accuracy: 1.0000 - val_loss: 0.8262 - val_accuracy: 0.8944 - lr: 2.5000e-04
# Epoch 114/200
# 28/28 [==============================] - ETA: 0s - loss: 1.2790e-04 - accuracy: 1.0000
# Epoch 00114: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 210ms/step - loss: 1.2790e-04 - accuracy: 1.0000 - val_loss: 0.7277 - val_accuracy: 0.9124 - lr: 2.5000e-04
# Epoch 115/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0560e-04 - accuracy: 1.0000
# Epoch 00115: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 211ms/step - loss: 1.0560e-04 - accuracy: 1.0000 - val_loss: 0.6981 - val_accuracy: 0.9236 - lr: 2.5000e-04
# Epoch 116/200
# 28/28 [==============================] - ETA: 0s - loss: 1.4315e-04 - accuracy: 1.0000
# Epoch 00116: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 207ms/step - loss: 1.4315e-04 - accuracy: 1.0000 - val_loss: 0.7381 - val_accuracy: 0.9169 - lr: 2.5000e-04
# Epoch 117/200
# 28/28 [==============================] - ETA: 0s - loss: 1.9428e-04 - accuracy: 1.0000
# Epoch 00117: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 210ms/step - loss: 1.9428e-04 - accuracy: 1.0000 - val_loss: 0.7301 - val_accuracy: 0.9169 - lr: 2.5000e-04
# Epoch 118/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0388e-04 - accuracy: 1.0000
# Epoch 00118: val_accuracy did not improve from 0.92360
# 28/28 [==============================] - 6s 207ms/step - loss: 1.0388e-04 - accuracy: 1.0000 - val_loss: 0.6968 - val_accuracy: 0.9236 - lr: 2.5000e-04
# Epoch 119/200
# 28/28 [==============================] - ETA: 0s - loss: 4.9824e-05 - accuracy: 1.0000
# Epoch 00119: val_accuracy improved from 0.92360 to 0.92584, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 6s 218ms/step - loss: 4.9824e-05 - accuracy: 1.0000 - val_loss: 0.7046 - val_accuracy: 0.9258 - lr: 2.5000e-04
# Epoch 120/200
# 28/28 [==============================] - ETA: 0s - loss: 1.6504e-04 - accuracy: 1.0000
# Epoch 00120: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 209ms/step - loss: 1.6504e-04 - accuracy: 1.0000 - val_loss: 0.6729 - val_accuracy: 0.9258 - lr: 2.5000e-04
# Epoch 121/200
# 28/28 [==============================] - ETA: 0s - loss: 7.5033e-05 - accuracy: 1.0000
# Epoch 00121: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 211ms/step - loss: 7.5033e-05 - accuracy: 1.0000 - val_loss: 0.6672 - val_accuracy: 0.9236 - lr: 2.5000e-04
# Epoch 122/200
# 28/28 [==============================] - ETA: 0s - loss: 2.7330e-04 - accuracy: 1.0000
# Epoch 00122: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 211ms/step - loss: 2.7330e-04 - accuracy: 1.0000 - val_loss: 0.7310 - val_accuracy: 0.9146 - lr: 2.5000e-04
# Epoch 123/200
# 28/28 [==============================] - ETA: 0s - loss: 3.1429e-04 - accuracy: 1.0000
# Epoch 00123: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 223ms/step - loss: 3.1429e-04 - accuracy: 1.0000 - val_loss: 0.7908 - val_accuracy: 0.9101 - lr: 2.5000e-04
# Epoch 124/200
# 28/28 [==============================] - ETA: 0s - loss: 8.4891e-05 - accuracy: 1.0000
# Epoch 00124: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 220ms/step - loss: 8.4891e-05 - accuracy: 1.0000 - val_loss: 0.8251 - val_accuracy: 0.9011 - lr: 2.5000e-04
# Epoch 125/200
# 28/28 [==============================] - ETA: 0s - loss: 2.0267e-04 - accuracy: 1.0000
# Epoch 00125: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 213ms/step - loss: 2.0267e-04 - accuracy: 1.0000 - val_loss: 1.3615 - val_accuracy: 0.8809 - lr: 2.5000e-04
# Epoch 126/200
# 28/28 [==============================] - ETA: 0s - loss: 2.2991e-04 - accuracy: 1.0000
# Epoch 00126: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 208ms/step - loss: 2.2991e-04 - accuracy: 1.0000 - val_loss: 1.2374 - val_accuracy: 0.8899 - lr: 2.5000e-04
# Epoch 127/200
# 28/28 [==============================] - ETA: 0s - loss: 2.3427e-04 - accuracy: 1.0000
# Epoch 00127: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 216ms/step - loss: 2.3427e-04 - accuracy: 1.0000 - val_loss: 1.1276 - val_accuracy: 0.8921 - lr: 2.5000e-04
# Epoch 128/200
# 28/28 [==============================] - ETA: 0s - loss: 5.0591e-04 - accuracy: 1.0000
# Epoch 00128: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 217ms/step - loss: 5.0591e-04 - accuracy: 1.0000 - val_loss: 0.8221 - val_accuracy: 0.9079 - lr: 2.5000e-04
# Epoch 129/200
# 28/28 [==============================] - ETA: 0s - loss: 3.6058e-04 - accuracy: 1.0000
# Epoch 00129: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 215ms/step - loss: 3.6058e-04 - accuracy: 1.0000 - val_loss: 0.7881 - val_accuracy: 0.8449 - lr: 2.5000e-04
# Epoch 130/200
# 28/28 [==============================] - ETA: 0s - loss: 1.5378e-04 - accuracy: 1.0000
# Epoch 00130: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 210ms/step - loss: 1.5378e-04 - accuracy: 1.0000 - val_loss: 0.6838 - val_accuracy: 0.9191 - lr: 2.5000e-04
# Epoch 131/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9994
# Epoch 00131: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 215ms/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 2.8367 - val_accuracy: 0.7146 - lr: 2.5000e-04
# Epoch 132/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9949
# Epoch 00132: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 210ms/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 7.3236 - val_accuracy: 0.5506 - lr: 2.5000e-04
# Epoch 133/200
# 28/28 [==============================] - ETA: 0s - loss: 3.9319e-04 - accuracy: 1.0000
# Epoch 00133: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 216ms/step - loss: 3.9319e-04 - accuracy: 1.0000 - val_loss: 5.3257 - val_accuracy: 0.6382 - lr: 2.5000e-04
# Epoch 134/200
# 28/28 [==============================] - ETA: 0s - loss: 3.7023e-04 - accuracy: 1.0000
# Epoch 00134: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 218ms/step - loss: 3.7023e-04 - accuracy: 1.0000 - val_loss: 2.5215 - val_accuracy: 0.7551 - lr: 2.5000e-04
# Epoch 135/200
# 28/28 [==============================] - ETA: 0s - loss: 2.3341e-04 - accuracy: 1.0000
# Epoch 00135: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 215ms/step - loss: 2.3341e-04 - accuracy: 1.0000 - val_loss: 1.2598 - val_accuracy: 0.8270 - lr: 2.5000e-04
# Epoch 136/200
# 28/28 [==============================] - ETA: 0s - loss: 3.8348e-04 - accuracy: 1.0000
# Epoch 00136: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 214ms/step - loss: 3.8348e-04 - accuracy: 1.0000 - val_loss: 1.0451 - val_accuracy: 0.8584 - lr: 2.5000e-04
# Epoch 137/200
# 28/28 [==============================] - ETA: 0s - loss: 2.3190e-04 - accuracy: 1.0000
# Epoch 00137: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 212ms/step - loss: 2.3190e-04 - accuracy: 1.0000 - val_loss: 0.8300 - val_accuracy: 0.8831 - lr: 2.5000e-04
# Epoch 138/200
# 28/28 [==============================] - ETA: 0s - loss: 1.5046e-04 - accuracy: 1.0000
# Epoch 00138: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 211ms/step - loss: 1.5046e-04 - accuracy: 1.0000 - val_loss: 0.7267 - val_accuracy: 0.9124 - lr: 2.5000e-04
# Epoch 139/200
# 28/28 [==============================] - ETA: 0s - loss: 6.6158e-05 - accuracy: 1.0000
# Epoch 00139: val_accuracy did not improve from 0.92584
#
# Epoch 00139: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 28/28 [==============================] - 6s 211ms/step - loss: 6.6158e-05 - accuracy: 1.0000 - val_loss: 0.6980 - val_accuracy: 0.9146 - lr: 2.5000e-04
# Epoch 140/200
# 28/28 [==============================] - ETA: 0s - loss: 4.1225e-04 - accuracy: 1.0000
# Epoch 00140: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 212ms/step - loss: 4.1225e-04 - accuracy: 1.0000 - val_loss: 0.6573 - val_accuracy: 0.9191 - lr: 1.2500e-04
# Epoch 141/200
# 28/28 [==============================] - ETA: 0s - loss: 1.8661e-04 - accuracy: 1.0000
# Epoch 00141: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 215ms/step - loss: 1.8661e-04 - accuracy: 1.0000 - val_loss: 0.6653 - val_accuracy: 0.9213 - lr: 1.2500e-04
# Epoch 142/200
# 28/28 [==============================] - ETA: 0s - loss: 1.8394e-04 - accuracy: 1.0000
# Epoch 00142: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 214ms/step - loss: 1.8394e-04 - accuracy: 1.0000 - val_loss: 0.6680 - val_accuracy: 0.9236 - lr: 1.2500e-04
# Epoch 143/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 00143: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 219ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.9685 - val_accuracy: 0.8742 - lr: 1.2500e-04
# Epoch 144/200
# 28/28 [==============================] - ETA: 0s - loss: 3.0538e-04 - accuracy: 1.0000
# Epoch 00144: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 7s 237ms/step - loss: 3.0538e-04 - accuracy: 1.0000 - val_loss: 0.9451 - val_accuracy: 0.8742 - lr: 1.2500e-04
# Epoch 145/200
# 28/28 [==============================] - ETA: 0s - loss: 9.7837e-05 - accuracy: 1.0000
# Epoch 00145: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 7s 238ms/step - loss: 9.7837e-05 - accuracy: 1.0000 - val_loss: 0.8524 - val_accuracy: 0.8989 - lr: 1.2500e-04
# Epoch 146/200
# 28/28 [==============================] - ETA: 0s - loss: 1.6757e-04 - accuracy: 1.0000
# Epoch 00146: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 7s 241ms/step - loss: 1.6757e-04 - accuracy: 1.0000 - val_loss: 0.7843 - val_accuracy: 0.9101 - lr: 1.2500e-04
# Epoch 147/200
# 28/28 [==============================] - ETA: 0s - loss: 5.8447e-05 - accuracy: 1.0000
# Epoch 00147: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 7s 235ms/step - loss: 5.8447e-05 - accuracy: 1.0000 - val_loss: 0.7528 - val_accuracy: 0.9124 - lr: 1.2500e-04
# Epoch 148/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0448e-04 - accuracy: 1.0000
# Epoch 00148: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 225ms/step - loss: 1.0448e-04 - accuracy: 1.0000 - val_loss: 0.7417 - val_accuracy: 0.9124 - lr: 1.2500e-04
# Epoch 149/200
# 28/28 [==============================] - ETA: 0s - loss: 1.5883e-04 - accuracy: 1.0000
# Epoch 00149: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 230ms/step - loss: 1.5883e-04 - accuracy: 1.0000 - val_loss: 0.7637 - val_accuracy: 0.9124 - lr: 1.2500e-04
# Epoch 150/200
# 28/28 [==============================] - ETA: 0s - loss: 3.3036e-04 - accuracy: 1.0000
# Epoch 00150: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 215ms/step - loss: 3.3036e-04 - accuracy: 1.0000 - val_loss: 0.7553 - val_accuracy: 0.9101 - lr: 1.2500e-04
# Epoch 151/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0606e-04 - accuracy: 1.0000
# Epoch 00151: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 213ms/step - loss: 1.0606e-04 - accuracy: 1.0000 - val_loss: 0.7372 - val_accuracy: 0.9124 - lr: 1.2500e-04
# Epoch 152/200
# 28/28 [==============================] - ETA: 0s - loss: 9.3669e-05 - accuracy: 1.0000
# Epoch 00152: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 216ms/step - loss: 9.3669e-05 - accuracy: 1.0000 - val_loss: 0.6733 - val_accuracy: 0.9258 - lr: 1.2500e-04
# Epoch 153/200
# 28/28 [==============================] - ETA: 0s - loss: 9.6878e-05 - accuracy: 1.0000
# Epoch 00153: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 215ms/step - loss: 9.6878e-05 - accuracy: 1.0000 - val_loss: 0.6706 - val_accuracy: 0.9258 - lr: 1.2500e-04
# Epoch 154/200
# 28/28 [==============================] - ETA: 0s - loss: 1.1386e-04 - accuracy: 1.0000
# Epoch 00154: val_accuracy did not improve from 0.92584
# 28/28 [==============================] - 6s 218ms/step - loss: 1.1386e-04 - accuracy: 1.0000 - val_loss: 0.6726 - val_accuracy: 0.9258 - lr: 1.2500e-04
# Epoch 155/200
# 28/28 [==============================] - ETA: 0s - loss: 1.4088e-04 - accuracy: 1.0000
# Epoch 00155: val_accuracy improved from 0.92584 to 0.92809, saving model to BiLSTM_V8_10.h5
# 28/28 [==============================] - 6s 222ms/step - loss: 1.4088e-04 - accuracy: 1.0000 - val_loss: 0.6645 - val_accuracy: 0.9281 - lr: 1.2500e-04
# Epoch 156/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0340e-04 - accuracy: 1.0000
# Epoch 00156: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 216ms/step - loss: 1.0340e-04 - accuracy: 1.0000 - val_loss: 0.6756 - val_accuracy: 0.9258 - lr: 1.2500e-04
# Epoch 157/200
# 28/28 [==============================] - ETA: 0s - loss: 4.8051e-05 - accuracy: 1.0000
# Epoch 00157: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 213ms/step - loss: 4.8051e-05 - accuracy: 1.0000 - val_loss: 0.6888 - val_accuracy: 0.9236 - lr: 1.2500e-04
# Epoch 158/200
# 28/28 [==============================] - ETA: 0s - loss: 4.5261e-05 - accuracy: 1.0000
# Epoch 00158: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 214ms/step - loss: 4.5261e-05 - accuracy: 1.0000 - val_loss: 0.6995 - val_accuracy: 0.9236 - lr: 1.2500e-04
# Epoch 159/200
# 28/28 [==============================] - ETA: 0s - loss: 5.1166e-05 - accuracy: 1.0000
# Epoch 00159: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 209ms/step - loss: 5.1166e-05 - accuracy: 1.0000 - val_loss: 0.7067 - val_accuracy: 0.9236 - lr: 1.2500e-04
# Epoch 160/200
# 28/28 [==============================] - ETA: 0s - loss: 3.3019e-05 - accuracy: 1.0000
# Epoch 00160: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 211ms/step - loss: 3.3019e-05 - accuracy: 1.0000 - val_loss: 0.7149 - val_accuracy: 0.9191 - lr: 1.2500e-04
# Epoch 161/200
# 28/28 [==============================] - ETA: 0s - loss: 2.4061e-04 - accuracy: 1.0000
# Epoch 00161: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 211ms/step - loss: 2.4061e-04 - accuracy: 1.0000 - val_loss: 0.6784 - val_accuracy: 0.9236 - lr: 1.2500e-04
# Epoch 162/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9989
# Epoch 00162: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 212ms/step - loss: 0.0018 - accuracy: 0.9989 - val_loss: 0.7933 - val_accuracy: 0.9146 - lr: 1.2500e-04
# Epoch 163/200
# 28/28 [==============================] - ETA: 0s - loss: 9.8477e-04 - accuracy: 1.0000
# Epoch 00163: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 209ms/step - loss: 9.8477e-04 - accuracy: 1.0000 - val_loss: 1.8671 - val_accuracy: 0.8629 - lr: 1.2500e-04
# Epoch 164/200
# 28/28 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9989
# Epoch 00164: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 209ms/step - loss: 0.0026 - accuracy: 0.9989 - val_loss: 1.2698 - val_accuracy: 0.8292 - lr: 1.2500e-04
# Epoch 165/200
# 28/28 [==============================] - ETA: 0s - loss: 1.4540e-04 - accuracy: 1.0000
# Epoch 00165: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 211ms/step - loss: 1.4540e-04 - accuracy: 1.0000 - val_loss: 1.1049 - val_accuracy: 0.8539 - lr: 1.2500e-04
# Epoch 166/200
# 28/28 [==============================] - ETA: 0s - loss: 1.8534e-04 - accuracy: 1.0000
# Epoch 00166: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 205ms/step - loss: 1.8534e-04 - accuracy: 1.0000 - val_loss: 0.9372 - val_accuracy: 0.8629 - lr: 1.2500e-04
# Epoch 167/200
# 28/28 [==============================] - ETA: 0s - loss: 1.5355e-04 - accuracy: 1.0000
# Epoch 00167: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 215ms/step - loss: 1.5355e-04 - accuracy: 1.0000 - val_loss: 0.7270 - val_accuracy: 0.8944 - lr: 1.2500e-04
# Epoch 168/200
# 28/28 [==============================] - ETA: 0s - loss: 1.1905e-04 - accuracy: 1.0000
# Epoch 00168: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 214ms/step - loss: 1.1905e-04 - accuracy: 1.0000 - val_loss: 0.6927 - val_accuracy: 0.9146 - lr: 1.2500e-04
# Epoch 169/200
# 28/28 [==============================] - ETA: 0s - loss: 9.8021e-05 - accuracy: 1.0000
# Epoch 00169: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 209ms/step - loss: 9.8021e-05 - accuracy: 1.0000 - val_loss: 0.6992 - val_accuracy: 0.9169 - lr: 1.2500e-04
# Epoch 170/200
# 28/28 [==============================] - ETA: 0s - loss: 2.2203e-04 - accuracy: 1.0000
# Epoch 00170: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 213ms/step - loss: 2.2203e-04 - accuracy: 1.0000 - val_loss: 0.7234 - val_accuracy: 0.9258 - lr: 1.2500e-04
# Epoch 171/200
# 28/28 [==============================] - ETA: 0s - loss: 7.9569e-05 - accuracy: 1.0000
# Epoch 00171: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 214ms/step - loss: 7.9569e-05 - accuracy: 1.0000 - val_loss: 0.7369 - val_accuracy: 0.9191 - lr: 1.2500e-04
# Epoch 172/200
# 28/28 [==============================] - ETA: 0s - loss: 4.9271e-05 - accuracy: 1.0000
# Epoch 00172: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 213ms/step - loss: 4.9271e-05 - accuracy: 1.0000 - val_loss: 0.7264 - val_accuracy: 0.9191 - lr: 1.2500e-04
# Epoch 173/200
# 28/28 [==============================] - ETA: 0s - loss: 2.7182e-04 - accuracy: 1.0000
# Epoch 00173: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 213ms/step - loss: 2.7182e-04 - accuracy: 1.0000 - val_loss: 0.6638 - val_accuracy: 0.9281 - lr: 1.2500e-04
# Epoch 174/200
# 28/28 [==============================] - ETA: 0s - loss: 1.5612e-04 - accuracy: 1.0000
# Epoch 00174: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 213ms/step - loss: 1.5612e-04 - accuracy: 1.0000 - val_loss: 0.6723 - val_accuracy: 0.9258 - lr: 1.2500e-04
# Epoch 175/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0973e-04 - accuracy: 1.0000
# Epoch 00175: val_accuracy did not improve from 0.92809
#
# Epoch 00175: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 28/28 [==============================] - 6s 211ms/step - loss: 1.0973e-04 - accuracy: 1.0000 - val_loss: 0.7449 - val_accuracy: 0.9213 - lr: 1.2500e-04
# Epoch 176/200
# 28/28 [==============================] - ETA: 0s - loss: 8.0827e-05 - accuracy: 1.0000
# Epoch 00176: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 214ms/step - loss: 8.0827e-05 - accuracy: 1.0000 - val_loss: 0.7355 - val_accuracy: 0.9191 - lr: 6.2500e-05
# Epoch 177/200
# 28/28 [==============================] - ETA: 0s - loss: 1.2505e-04 - accuracy: 1.0000
# Epoch 00177: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 223ms/step - loss: 1.2505e-04 - accuracy: 1.0000 - val_loss: 0.7416 - val_accuracy: 0.9191 - lr: 6.2500e-05
# Epoch 178/200
# 28/28 [==============================] - ETA: 0s - loss: 4.6324e-05 - accuracy: 1.0000
# Epoch 00178: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 7s 243ms/step - loss: 4.6324e-05 - accuracy: 1.0000 - val_loss: 0.7408 - val_accuracy: 0.9169 - lr: 6.2500e-05
# Epoch 179/200
# 28/28 [==============================] - ETA: 0s - loss: 1.1428e-04 - accuracy: 1.0000
# Epoch 00179: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 217ms/step - loss: 1.1428e-04 - accuracy: 1.0000 - val_loss: 0.7327 - val_accuracy: 0.9191 - lr: 6.2500e-05
# Epoch 180/200
# 28/28 [==============================] - ETA: 0s - loss: 8.3774e-05 - accuracy: 1.0000
# Epoch 00180: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 214ms/step - loss: 8.3774e-05 - accuracy: 1.0000 - val_loss: 0.7329 - val_accuracy: 0.9191 - lr: 6.2500e-05
# Epoch 181/200
# 28/28 [==============================] - ETA: 0s - loss: 2.6045e-05 - accuracy: 1.0000
# Epoch 00181: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 215ms/step - loss: 2.6045e-05 - accuracy: 1.0000 - val_loss: 0.7317 - val_accuracy: 0.9191 - lr: 6.2500e-05
# Epoch 182/200
# 28/28 [==============================] - ETA: 0s - loss: 9.6483e-05 - accuracy: 1.0000
# Epoch 00182: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 219ms/step - loss: 9.6483e-05 - accuracy: 1.0000 - val_loss: 0.7292 - val_accuracy: 0.9191 - lr: 6.2500e-05
# Epoch 183/200
# 28/28 [==============================] - ETA: 0s - loss: 1.0586e-04 - accuracy: 1.0000
# Epoch 00183: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 211ms/step - loss: 1.0586e-04 - accuracy: 1.0000 - val_loss: 0.7257 - val_accuracy: 0.9146 - lr: 6.2500e-05
# Epoch 184/200
# 28/28 [==============================] - ETA: 0s - loss: 4.9089e-05 - accuracy: 1.0000
# Epoch 00184: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 215ms/step - loss: 4.9089e-05 - accuracy: 1.0000 - val_loss: 0.7302 - val_accuracy: 0.9146 - lr: 6.2500e-05
# Epoch 185/200
# 28/28 [==============================] - ETA: 0s - loss: 4.5472e-04 - accuracy: 1.0000
# Epoch 00185: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 212ms/step - loss: 4.5472e-04 - accuracy: 1.0000 - val_loss: 0.7514 - val_accuracy: 0.9146 - lr: 6.2500e-05
# Epoch 186/200
# 28/28 [==============================] - ETA: 0s - loss: 1.7977e-04 - accuracy: 1.0000
# Epoch 00186: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 214ms/step - loss: 1.7977e-04 - accuracy: 1.0000 - val_loss: 0.9972 - val_accuracy: 0.8921 - lr: 6.2500e-05
# Epoch 187/200
# 28/28 [==============================] - ETA: 0s - loss: 7.6595e-05 - accuracy: 1.0000
# Epoch 00187: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 217ms/step - loss: 7.6595e-05 - accuracy: 1.0000 - val_loss: 0.9339 - val_accuracy: 0.8966 - lr: 6.2500e-05
# Epoch 188/200
# 28/28 [==============================] - ETA: 0s - loss: 1.3648e-04 - accuracy: 1.0000
# Epoch 00188: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 209ms/step - loss: 1.3648e-04 - accuracy: 1.0000 - val_loss: 0.9156 - val_accuracy: 0.9056 - lr: 6.2500e-05
# Epoch 189/200
# 28/28 [==============================] - ETA: 0s - loss: 2.4698e-04 - accuracy: 1.0000
# Epoch 00189: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 211ms/step - loss: 2.4698e-04 - accuracy: 1.0000 - val_loss: 0.8647 - val_accuracy: 0.9011 - lr: 6.2500e-05
# Epoch 190/200
# 28/28 [==============================] - ETA: 0s - loss: 7.5020e-05 - accuracy: 1.0000
# Epoch 00190: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 209ms/step - loss: 7.5020e-05 - accuracy: 1.0000 - val_loss: 0.8355 - val_accuracy: 0.9011 - lr: 6.2500e-05
# Epoch 191/200
# 28/28 [==============================] - ETA: 0s - loss: 4.5421e-05 - accuracy: 1.0000
# Epoch 00191: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 217ms/step - loss: 4.5421e-05 - accuracy: 1.0000 - val_loss: 0.8082 - val_accuracy: 0.9079 - lr: 6.2500e-05
# Epoch 192/200
# 28/28 [==============================] - ETA: 0s - loss: 2.1775e-04 - accuracy: 1.0000
# Epoch 00192: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 210ms/step - loss: 2.1775e-04 - accuracy: 1.0000 - val_loss: 0.7404 - val_accuracy: 0.9101 - lr: 6.2500e-05
# Epoch 193/200
# 28/28 [==============================] - ETA: 0s - loss: 6.2304e-05 - accuracy: 1.0000
# Epoch 00193: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 208ms/step - loss: 6.2304e-05 - accuracy: 1.0000 - val_loss: 0.7197 - val_accuracy: 0.9146 - lr: 6.2500e-05
# Epoch 194/200
# 28/28 [==============================] - ETA: 0s - loss: 4.3892e-05 - accuracy: 1.0000
# Epoch 00194: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 210ms/step - loss: 4.3892e-05 - accuracy: 1.0000 - val_loss: 0.7252 - val_accuracy: 0.9146 - lr: 6.2500e-05
# Epoch 195/200
# 28/28 [==============================] - ETA: 0s - loss: 7.2832e-05 - accuracy: 1.0000
# Epoch 00195: val_accuracy did not improve from 0.92809
#
# Epoch 00195: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 28/28 [==============================] - 6s 211ms/step - loss: 7.2832e-05 - accuracy: 1.0000 - val_loss: 0.7345 - val_accuracy: 0.9146 - lr: 6.2500e-05
# Epoch 196/200
# 28/28 [==============================] - ETA: 0s - loss: 5.9167e-05 - accuracy: 1.0000
# Epoch 00196: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 209ms/step - loss: 5.9167e-05 - accuracy: 1.0000 - val_loss: 0.7362 - val_accuracy: 0.9146 - lr: 3.1250e-05
# Epoch 197/200
# 28/28 [==============================] - ETA: 0s - loss: 5.9685e-05 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 213ms/step - loss: 5.9685e-05 - accuracy: 1.0000 - val_loss: 0.7367 - val_accuracy: 0.9146 - lr: 3.1250e-05
# Epoch 198/200
# 28/28 [==============================] - ETA: 0s - loss: 2.8085e-05 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 210ms/step - loss: 2.8085e-05 - accuracy: 1.0000 - val_loss: 0.7390 - val_accuracy: 0.9124 - lr: 3.1250e-05
# Epoch 199/200
# 28/28 [==============================] - ETA: 0s - loss: 3.2064e-05 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 214ms/step - loss: 3.2064e-05 - accuracy: 1.0000 - val_loss: 0.7376 - val_accuracy: 0.9124 - lr: 3.1250e-05
# Epoch 200/200
# 28/28 [==============================] - ETA: 0s - loss: 5.4604e-05 - accuracy: 1.0000
# Epoch 00200: val_accuracy did not improve from 0.92809
# 28/28 [==============================] - 6s 211ms/step - loss: 5.4604e-05 - accuracy: 1.0000 - val_loss: 0.7413 - val_accuracy: 0.9124 - lr: 3.1250e-05

# %%
# 可视化训练过程中，训练集与验证集的损失和精度
plt.figure(figsize=(16,8))
plt.subplot(121)
plt.plot(history.history['loss'],label = 'train_loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()

plt.subplot(122)
plt.plot(history.history['accuracy'],label = 'train_accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()

# %%
# 使用模型得到预测结果
model = load_model('BiLSTM_V8_10.h5')
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

# %%
print('在80%训练集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1)), recall_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary'), f1_score(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1), average='binary')))
print('在20%测试集上, accuracy: {:.4}% 召回率: {:4}, f1: {:4}'.format(accuracy_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1)), recall_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary'), f1_score(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1), average='binary')))
# Out:
# 在80%训练集上, accuracy: 1.0% 召回率:  1.0, f1:  1.0
# 在20%测试集上, accuracy: 0.9281% 召回率: 0.9414225941422594, f1: 0.9336099585062242

# %%
# 绘制混淆矩阵
plt.figure(figsize=(16,8))
plt.subplot(121)
matrix = confusion_matrix(np.argmax(y_train, axis = 1), np.argmax(y_train_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Train confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.subplot(122)
matrix = confusion_matrix(np.argmax(y_test, axis = 1), np.argmax(y_test_pred, axis = 1))
sns.heatmap(matrix,annot=True,cmap="Blues",fmt='g') 
plt.title('Test confusion matrix') 
plt.xticks(range(2), ['Negative', 'Positive'])
plt.yticks(range(2), ['Negative', 'Positive'])
plt.xlabel('Predict') 
plt.ylabel('True')
plt.show()
